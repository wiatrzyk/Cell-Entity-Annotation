# %% [markdown]
# # ISWC 2019 Cell-Entity Annotation (CEA) Challenge
# https://www.aicrowd.com/challenges/iswc-2019-cell-entity-annotation-cea-challenge
#
# ## Opis zadania
#
# Zadanie polega na anotacji zawartości poszczególnych komórek z jednostkami dbpedii o prefiksie “http://dbpedia.org/resource/”. Jedna komórka może być powiązana z tylko jednym zasobem.
# Końcowym wynikiem powinien być plik zawierający informacje o id tabeli oraz wierszu i kolumnie w jakim znajduje się komórka wraz z anotacją. Np.
# “9206866_1_8114610355671172497”,”0”,”121”,”http://dbpedia.org/resource/Norway”

# %% [markdown]
# ## Przygotowanie środowiska
#
# Instalacja bibliotek wymaganych do prawidłowego uruchomienia notatnika.

# %%
# %pip install pandas==1.3.4
# %pip install requests==2.26.0
# %pip install python-Levenshtein==0.12.2
# %pip install spotlight==2.3.2
# Out:
# Requirement already satisfied: pandas==1.3.4 in e:\pytong\cea\.venv\lib\site-packages (1.3.4)
# Requirement already satisfied: pytz>=2017.3 in e:\pytong\cea\.venv\lib\site-packages (from pandas==1.3.4) (2021.3)
# Requirement already satisfied: numpy>=1.17.3; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in e:\pytong\cea\.venv\lib\site-packages (from pandas==1.3.4) (1.22.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in e:\pytong\cea\.venv\lib\site-packages (from pandas==1.3.4) (2.8.2)
# Requirement already satisfied: six>=1.5 in e:\pytong\cea\.venv\lib\site-packages (from python-dateutil>=2.7.3->pandas==1.3.4) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'e:\pytong\CEA\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: requests==2.26.0 in e:\pytong\cea\.venv\lib\site-packages (2.26.0)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in e:\pytong\cea\.venv\lib\site-packages (from requests==2.26.0) (2.0.10)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in e:\pytong\cea\.venv\lib\site-packages (from requests==2.26.0) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in e:\pytong\cea\.venv\lib\site-packages (from requests==2.26.0) (1.26.8)
# Requirement already satisfied: certifi>=2017.4.17 in e:\pytong\cea\.venv\lib\site-packages (from requests==2.26.0) (2021.10.8)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'e:\pytong\CEA\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: python-Levenshtein==0.12.2 in e:\pytong\cea\.venv\lib\site-packages (0.12.2)
# Requirement already satisfied: setuptools in e:\pytong\cea\.venv\lib\site-packages (from python-Levenshtein==0.12.2) (49.2.1)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'e:\pytong\CEA\.venv\Scripts\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: spotlight==2.3.2 in e:\pytong\cea\.venv\lib\site-packages (2.3.2)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 20.2.3; however, version 21.3.1 is available.
# You should consider upgrading via the 'e:\pytong\CEA\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %% [markdown]
# ### Ekstrakcja danych
#
# Na samym początku należy wyodrębnić dane do pracy. Do zadania został dołączony zbiór plików csv, gdzie jeden plik odpowiada jednej tabeli, a jego nazwa określa id tej tabeli. Pliki te nie zawierają wiersza nagłówkowego.
# Dodatkowo dostarczony jest plik w którym znajdują się informacje o docelowych komórkach do anotacji (id tabeli, wiersz oraz kolumna komórki).
# Ilość komórek do anotacji wynosi łącznie 8418.
#
# Za pomocą poniższego kodu odczytywana jest zawartość plików (tabel) oraz wyszukiwane docelowe wartości komórek do anotacji.

# %%
import pandas as pd

# Load data
df_target = pd.read_csv("data/Round 1/targets/CEA_Round1_Targets.csv", header=None)
df_target.columns = ["Table_id", "Column_id", "Row_id"]

# Read all targets and find them in data tables
df_target = df_target.assign(text=None)
for index, row in df_target.iterrows():
    try:
        table_id = row['Table_id']
        column_id = int(row['Column_id'])
        row_id = int(row['Row_id'])
        table = pd.read_csv(f'data/Round 1/tables/{table_id}.csv', header=None)
        text = table.loc[row_id][column_id]
        df_target.loc[index, 'text'] = text
    except Exception as exc:
        print(f"EXCEPTION {exc}")

# %%
df_target.head()
# Out:
#                          Table_id  Column_id  Row_id  \
# 0   50245608_0_871275842592178099          0     154
# 1  39107734_2_2329160387535788734          1      32
# 2  22864497_0_8632623712684511496          0     227
# 3  66009064_0_9148652238372261251          0      15
# 4  21362676_0_6854186738074119688          1      75
#
#                                            text
# 0                                  Pearl Harbor
# 1  Minneapolis-Saint Paul International Airport
# 2                        Need for Speed: Carbon
# 3                                Alex Rodriguez
# 4                                     King Kong

# %% [markdown]
# ### Czyszczenie danych
#
# Następnie przeszliśmy do wyczyszczenia uzyskanych z komórek tekstów ze znaków specjalnych, które mogłyby w kolejnych krokach utrudniać zadanie. Dostosowanie zbioru znaków do usunięcia wymagało kilku iteracji i porównania skuteczności zachowania dalszych kroków. W ten sposób zauważyliśmy na przykład, że lepsze wyniki są uzyskiwanie kiedy w tekście pozostawiany jest znak myślnika (“-”) niż w przypadku gdy jest on pomijany.
#
# Poniższa funkcja przyjmuje tekst i zwraca jego wersję bez znaków uznanych za utrudniające anotacje.

# %%
chars = '!"#$%&\'()*+,./:;<=>?@[\\]^`{|}~'

def clear_entity(cell_entity: str) -> str:
    if not isinstance(cell_entity, str):
        return cell_entity
    clear_cell = ""
    for ch in cell_entity:
        if ch not in chars:
            clear_cell += ch
    return clear_cell.strip()
    
df_target['text'] = df_target['text'].map(clear_entity)

# %%
df_target.head()
# Out:
#                          Table_id  Column_id  Row_id  \
# 0   50245608_0_871275842592178099          0     154
# 1  39107734_2_2329160387535788734          1      32
# 2  22864497_0_8632623712684511496          0     227
# 3  66009064_0_9148652238372261251          0      15
# 4  21362676_0_6854186738074119688          1      75
#
#                                            text
# 0                                  Pearl Harbor
# 1  Minneapolis-Saint Paul International Airport
# 2                         Need for Speed Carbon
# 3                                Alex Rodriguez
# 4                                     King Kong

# %% [markdown]
# ## Anotacja
#
# Po przygotowaniu danych mogliśmy przejść do docelowego zadania - anotacji. Ten etap rozpoczęliśmy od zapoznania się z dokumentami stworzonymi przez uczestników konkursu, którzy uzyskali najlepsze wyniki w rankingu. Przekrój stworzonych rozwiązań był bardzo różnorodny, więc ostatecznie zadecydowaliśmy się wykorzystać kilka sposobów, połączyć je ze sobą i porównać uzyskane wyniki. Ostatecznie zadecydowaliśmy się wykorzystać 3 sposoby wyznaczania połączeń z dbpedią. Naszym celem było zebranie kandydatów wyłonionych za pomocą każdego z nich i ostatecznie na samym końcu wyłonienie najlepiej pasującej strony.

# %% [markdown]
# ### Samodzielne tworzenie adresu URL
#
# Pierwsze, zdecydowanie najprostsze rozwiązanie, zakłada wykorzystanie wzoru zgodnie z którym są tworzone adresy url dla zasobów dbpedii. Każdy z takich zasobów rozpoczyna się prefiksem “http://dbpedia.org/resource/” a następny element odpowiada nazwie zasobu. Wykorzystując tą wiedze można w tekście do anotacji zamienić znak spacji na znak podkreślenia (”_”), a następnię dołączenie go do znanego prefiksu. Dzięki temu tworzony jest adres odpowiadający strukturą zasobom znajdującym się na stronie. W tym momencie można przejść do odpytania samodzielnie stworzonego adresu i jeśli w odpowiedzi otrzymany jest prawidłowy kod statusu, to zasób o danym adresie istnieje. Można założyć z dużym prawdopodobieństwem że jest to szukany wynik.

# %%
import requests

def check_url(enity_value: str):
    try:
        parsed_data = enity_value.replace(" ", "_")
        url = f'http://dbpedia.org/resource/{parsed_data}'
        resp = requests.get(url, headers={'Connection': 'close'})
        assert resp.status_code == 200
        return url
    except AssertionError:
        # Invalid url
        return None

    except Exception as exc:
        print(f"EXC {exc}")
        return None

# %%
check_url("Buddy Rosar")
# Out:
# 'http://dbpedia.org/resource/Buddy_Rosar'

# %% [markdown]
# ### DBpedia Lookup Service - Auto-Complete API
#
# DBpedia Lookup Service jest to usługa wyszukiwania zwracająca jednostki DBpedii. Może zostać skonfigurowana na łączenie słów kluczowych z identyfikatorami zasobów. Każdy tak uzyskany wynik posiada liczbę wyznaczaną na podstawie dopasowań etykiet oraz innych czynników. Możliwe jest ograniczenie zwracanych wyników o wymaganie miimalnej jej wartości. Pozwala to na odrzucenie wyników które mają małe prawdopodobieństwo na okazanie się docelowo szukanymi.
#
# W trakcie wykonywania zadania napotkaliśmy problem, gdy serwer hostowany przez dbpedie przestał działać i każde zapytanie zwracało kod statusu 500. W takiej sytuacji wykorzystaliśmy kod udostępniony na github.com oraz już zbudowane obrazy dockerowe. Z ich pomocą uruchomiliśmy aplikacje lokalnie. Pozwoliło nam to na dalsze testy i prace. Wykorzystane wersje różnią się minimalnie między sobą dlatego poniżej znajdują się 2 rozwiązania pozyskania wyników w zależności od wykorzystania serwisu udostępnianego publicznie lub samodzielnego hostowania lokalnego.

# %%
import requests
import xmltodict
import urllib3
requests.urllib3.disable_warnings(urllib3.exceptions.InsecureRequestWarning)

def dbpedia_lookup(enity_value: str, max_hits=20):
    url = f'https://lookup.dbpedia.org/api/search/KeywordSearch?MaxHits={max_hits}&QueryString="{enity_value}"'
    # url = f'http://localhost:9274/lookup-application/api/search?query={enity_value}&maxResults={max_hits}'
    try:
        resp = requests.get(url, headers={'Connection': 'close'}, verify=False)
        if resp.status_code != 200:
            print('Service Unavailable')
            return []
        result_tree = xmltodict.parse(resp.content.decode('utf-8'))
        if result_tree['ArrayOfResults'] is None or 'Result' not in result_tree['ArrayOfResults']:
            print(enity_value)
            return []
        result = result_tree['ArrayOfResults']['Result']
        if isinstance(result, list):
            return [r['URI'] for r in result]

        return [result['URI']]
    except Exception as exc:
        print(f"EXC {exc}, {enity_value}")

# %%
dbpedia_lookup('Lappet-faced vulture')
# Out:
# ['http://dbpedia.org/resource/Lappet-faced_vulture']

# %% [markdown]
# ### DBPedia Spotlight API
#
# DBpedia Spotlight jest to narzędzie pozwalające na automatyczne dodawanie adnotacji do wzmianek zasobów DBpedii w tekście. Zapewnia rozwiązanie do łączenia nieustrukturyzowanych źródeł informacji z zasobami DBpedii. Zdecydowanie bardziej złożone rozwiązanie w porównaniu do poprzednich sposobów. Wykorzystuje 4-stopniowy proces rozpoznawania danych, bazując na kontekście w jakim występuje tekst. Sposób wykorzystania w naszym przypadku nie jest więc optymalny. Na pewno lepiej  odpowiadałby na potrzebe anotacji dłuższych tekstów (kolumn lub nawet całych tabel).
#
#
# Istnieje możliwość analogicznego uruchomienia systemu lokalnie jak w przypadku DBpedia Lookup Service, ale nie wystąpiły żadne problemy z dostępnym api, więc do tego zadania zdecydowaliśmy się je wykorzystać.

# %%
import requests


def spotlight_lookup(text, lang='en', confidence=0.01):
    url = f"https://api.dbpedia-spotlight.org/{lang}/annotate"
    params = {'text': text, 'confidence':confidence}
    headers = {'accept': 'application/json'}

    try:
        response = requests.request("GET", url, headers=headers, params=params)
        results = response.json()['Resources']
        matches = []
        for result in results:
            uri = result['@URI']         
            matches.append(uri.replace('/page/', '/resource/'))
    except Exception as e:
        print(f'[SPOTLIGHT] Something went wrong with text: {text}. Returning nothing')
        return []

    return matches

# %%
spotlight_lookup("Lappet-faced vulture")
# Out:
# ['http://dbpedia.org/resource/Lappet-faced_vulture']

# %% [markdown]
# ## Wyniki

# %% [markdown]
# ### Odległość Levenshtein’a
#
# Do wytypowania najlepszego wyniku zdecydowaliśmy się na wykorzystanie odległości Levenshtein’a. Oznacza ona najmniejszą liczbę działań prostych, przeprowadzająca jeden napis w drugi.

# %%
import Levenshtein

def find_best_match(urls, cell_value):
    min_distance = 9999
    value = ''
    for url in urls:
        label = url.split('resource')[1][1:].replace('_', ' ')
        levenshtein_distance = Levenshtein.distance(cell_value.lower(), label.lower())
        if min_distance > levenshtein_distance:
            value = url
            min_distance = levenshtein_distance

    return value, min_distance

# %% [markdown]
# Ostateczne wyznaczenie wyników za pomocą wszystkich sposobów i wyłonienie potencjalnych kandydatów ostatecznego wyniku.

# %%
import pandas as pd  


def save_results(cell, index, urls, dataframe, filename):
        # Levenshtein
        best_match, distance = find_best_match(urls, cell)

        # save_results
        dataframe.loc[index, 'annotation'] = best_match
        dataframe.loc[index, 'candidates'] = str(urls)

        print(cell, best_match, distance)
        dataframe.to_csv(f'{filename}_results.csv', sep=',', index=False, )


def annotate(cleared_data: pd.DataFrame):
    result_df = cleared_data.assign(annotation=None, candidates=None)
    
    url_check_results = result_df.copy()
    dbpedia_lookup_results_df = result_df.copy()
    spotlight_lookup_results_df = result_df.copy()
    
    for index, row in result_df.iterrows():
        cell = row['text']
        if not isinstance(cell, str):
            continue
        
        result_candidates = []
        
        # CHECK
        url = check_url(cell)
        if url is not None:
            result_candidates.append(url)
            save_results(cell, index, [url], url_check_results, 'check_url')
        
        # DBPEDIA
        dbpedia_lookup_urls = dbpedia_lookup(cell, 10)
        for url in dbpedia_lookup_urls:
            result_candidates.append(url)
        save_results(cell, index, dbpedia_lookup_urls, dbpedia_lookup_results_df, 'dbpedia_lookup')
        
        # SPOTLIGHT
        spotlight_lookup_urls = spotlight_lookup(cell)
        for url in spotlight_lookup_urls:
            if url not in result_candidates:
                result_candidates.append(url)
        save_results(cell, index, spotlight_lookup_urls, spotlight_lookup_results_df, 'spotlight_lookup')

        save_results(cell, index, result_candidates, result_df, 'all')

# %%
annotate(df_target)
# Out:
# Pearl Harbor http://dbpedia.org/resource/Pearl_Harbor 0
# Pearl Harbor http://dbpedia.org/resource/Pearl_Harbor 0
# Pearl Harbor http://dbpedia.org/resource/Pearl_Harbor 0
# Pearl Harbor http://dbpedia.org/resource/Pearl_Harbor 0
# Minneapolis-Saint Paul International Airport http://dbpedia.org/resource/Minneapolis-Saint_Paul_International_Airport 0
# Minneapolis-Saint Paul International Airport http://dbpedia.org/resource/Minneapolis–Saint_Paul_International_Airport 1
# Minneapolis-Saint Paul International Airport http://dbpedia.org/resource/Minneapolis–Saint_Paul_International_Airport 1
# Minneapolis-Saint Paul International Airport http://dbpedia.org/resource/Minneapolis-Saint_Paul_International_Airport 0
# Need for Speed Carbon http://dbpedia.org/resource/Need_for_Speed_Carbon 0
# Need for Speed Carbon http://dbpedia.org/resource/Need_for_Speed:_Carbon 1
# Need for Speed Carbon http://dbpedia.org/resource/Carbon 15
# Need for Speed Carbon http://dbpedia.org/resource/Need_for_Speed_Carbon 0
# Alex Rodriguez http://dbpedia.org/resource/Alex_Rodriguez 0
# Alex Rodriguez http://dbpedia.org/resource/Alex_Rodriguez 0
# Alex Rodriguez http://dbpedia.org/resource/Alex_Rodriguez 0
# Alex Rodriguez http://dbpedia.org/resource/Alex_Rodriguez 0
# King Kong http://dbpedia.org/resource/King_Kong 0
# King Kong http://dbpedia.org/resource/King_Kong 0
# King Kong http://dbpedia.org/resource/King_Kong 0
# King Kong http://dbpedia.org/resource/King_Kong 0
# School of Rock  The
# School of Rock  The  9999
# School of Rock  The http://dbpedia.org/resource/School 13
# School of Rock  The http://dbpedia.org/resource/School 13
# Lex Luger http://dbpedia.org/resource/Lex_Luger 0
# Lex Luger http://dbpedia.org/resource/Lex_Luger 0
# Lex Luger http://dbpedia.org/resource/Lex_Luger 0
# Lex Luger http://dbpedia.org/resource/Lex_Luger 0
# Crash Bash http://dbpedia.org/resource/Crash_Bash 0
# Crash Bash http://dbpedia.org/resource/Crash_Bash 0
# Crash Bash http://dbpedia.org/resource/Crash_Bash 0
# Crash Bash http://dbpedia.org/resource/Crash_Bash 0
# The Hurt Locker http://dbpedia.org/resource/The_Hurt_Locker 0
# The Hurt Locker http://dbpedia.org/resource/The_Hurt_Locker 0
# The Hurt Locker http://dbpedia.org/resource/The_Hurt_Locker 0
# The Hurt Locker http://dbpedia.org/resource/The_Hurt_Locker 0
# Lion http://dbpedia.org/resource/Lion 0
# Lion http://dbpedia.org/resource/Lion 0
# Lion http://dbpedia.org/resource/Lion 0
# Lion http://dbpedia.org/resource/Lion 0
# Lac-Seul
# Lac-Seul  9999
# [SPOTLIGHT] Something went wrong with text: Lac-Seul. Returning nothing
# Lac-Seul  9999
# Lac-Seul  9999
# Fear and Loathing in Las Vegas http://dbpedia.org/resource/Fear_and_Loathing_in_Las_Vegas 0
# Fear and Loathing in Las Vegas http://dbpedia.org/resource/Fear_and_Loathing_in_Las_Vegas 0
# Fear and Loathing in Las Vegas http://dbpedia.org/resource/Las_Vegas_Valley 24
# Fear and Loathing in Las Vegas http://dbpedia.org/resource/Fear_and_Loathing_in_Las_Vegas 0
# Max Weber http://dbpedia.org/resource/Max_Weber 0
# Max Weber http://dbpedia.org/resource/Max_Weber 0
# Max Weber http://dbpedia.org/resource/Max_Weber 0
# Max Weber http://dbpedia.org/resource/Max_Weber 0
# Kidsty Pike http://dbpedia.org/resource/Kidsty_Pike 0
# Kidsty Pike http://dbpedia.org/resource/Kidsty_Pike 0
# Kidsty Pike http://dbpedia.org/resource/Kidsty_Pike 0
# Kidsty Pike http://dbpedia.org/resource/Kidsty_Pike 0
# Randy Johnson http://dbpedia.org/resource/Randy_Johnson 0
# Randy Johnson http://dbpedia.org/resource/Randy_Johnson 0
# Randy Johnson http://dbpedia.org/resource/Randy_Johnson 0
# Randy Johnson http://dbpedia.org/resource/Randy_Johnson 0
# TimeShift http://dbpedia.org/resource/TimeShift 0
# TimeShift http://dbpedia.org/resource/TimeShift 0
# TimeShift http://dbpedia.org/resource/TimeShift 0
# TimeShift http://dbpedia.org/resource/TimeShift 0
# Batman Arkham City http://dbpedia.org/resource/Batman_Arkham_City 0
# Batman Arkham City http://dbpedia.org/resource/Batman:_Arkham_City 1
# Batman Arkham City http://dbpedia.org/resource/Batman 12
# Batman Arkham City http://dbpedia.org/resource/Batman_Arkham_City 0
# Dazzy Vance http://dbpedia.org/resource/Dazzy_Vance 0
# Dazzy Vance http://dbpedia.org/resource/Dazzy_Vance 0
# Dazzy Vance http://dbpedia.org/resource/Dazzy_Vance 0
# Dazzy Vance http://dbpedia.org/resource/Dazzy_Vance 0
# A Clockwork Orange http://dbpedia.org/resource/A_Clockwork_Orange 0
# A Clockwork Orange http://dbpedia.org/resource/A_Clockwork_Orange 0
# A Clockwork Orange http://dbpedia.org/resource/A_Clockwork_Orange_(film) 7
# A Clockwork Orange http://dbpedia.org/resource/A_Clockwork_Orange 0
# Bill Collins http://dbpedia.org/resource/Bill_Collins 0
# Bill Collins http://dbpedia.org/resource/Bill_Collins 0
# Bill Collins http://dbpedia.org/resource/Bill_Collins_(television_presenter) 23
# Bill Collins http://dbpedia.org/resource/Bill_Collins 0
# Greenland http://dbpedia.org/resource/Greenland 0
# Greenland http://dbpedia.org/resource/Greenland 0
# Greenland http://dbpedia.org/resource/Greenland 0
# Greenland http://dbpedia.org/resource/Greenland 0
# Thunbergia grandiflora http://dbpedia.org/resource/Thunbergia_grandiflora 0
# Thunbergia grandiflora http://dbpedia.org/resource/Thunbergia_grandiflora 0
# Thunbergia grandiflora http://dbpedia.org/resource/Thunbergia 12
# Thunbergia grandiflora http://dbpedia.org/resource/Thunbergia_grandiflora 0
# Peter of Sebaste http://dbpedia.org/resource/Peter_of_Sebaste 0
# Peter of Sebaste http://dbpedia.org/resource/Peter_of_Sebaste 0
# [SPOTLIGHT] Something went wrong with text: Peter of Sebaste. Returning nothing
# Peter of Sebaste  9999
# Peter of Sebaste http://dbpedia.org/resource/Peter_of_Sebaste 0
# Jimmy Ryan http://dbpedia.org/resource/Jimmy_Ryan 0
# Jimmy Ryan http://dbpedia.org/resource/Jimmy_Ryan 0
# Jimmy Ryan http://dbpedia.org/resource/Jimmy_Ryan_(baseball) 11
# Jimmy Ryan http://dbpedia.org/resource/Jimmy_Ryan 0
# State Hermitage Museum http://dbpedia.org/resource/State_Hermitage_Museum 0
# State Hermitage Museum http://dbpedia.org/resource/Hermitage_Museum 6
# State Hermitage Museum http://dbpedia.org/resource/Hermitage_Museum 6
# State Hermitage Museum http://dbpedia.org/resource/State_Hermitage_Museum 0
# Mario Party 8 http://dbpedia.org/resource/Mario_Party_8 0
# Mario Party 8 http://dbpedia.org/resource/Mario_Party_8 0
# Mario Party 8 http://dbpedia.org/resource/Mario_Party 2
# Mario Party 8 http://dbpedia.org/resource/Mario_Party_8 0
# Lygodium palmatum http://dbpedia.org/resource/Lygodium_palmatum 0
# Lygodium palmatum http://dbpedia.org/resource/Lygodium_palmatum 0
# Lygodium palmatum http://dbpedia.org/resource/Lygodium_palmatum 0
# Lygodium palmatum http://dbpedia.org/resource/Lygodium_palmatum 0
# New Taiwan Dollar http://dbpedia.org/resource/New_Taiwan_Dollar 0
# New Taiwan Dollar http://dbpedia.org/resource/New_Taiwan_dollar 0
# New Taiwan Dollar http://dbpedia.org/resource/New_Taiwan_dollar 0
# New Taiwan Dollar http://dbpedia.org/resource/New_Taiwan_Dollar 0
# Mary Poppins http://dbpedia.org/resource/Mary_Poppins 0
# Mary Poppins http://dbpedia.org/resource/Mary_Poppins 0
# Mary Poppins http://dbpedia.org/resource/Mary_Poppins_(film) 7
# Mary Poppins http://dbpedia.org/resource/Mary_Poppins 0
# The Curse of Monkey Island http://dbpedia.org/resource/The_Curse_of_Monkey_Island 0
# The Curse of Monkey Island http://dbpedia.org/resource/The_Curse_of_Monkey_Island 0
# The Curse of Monkey Island http://dbpedia.org/resource/The_Secret_of_Monkey_Island 5
# The Curse of Monkey Island http://dbpedia.org/resource/The_Curse_of_Monkey_Island 0
# Super Mario All-Stars  Super Mario World
# Super Mario All-Stars  Super Mario World  9999
# Super Mario All-Stars  Super Mario World http://dbpedia.org/resource/Super_Mario_All-Stars 19
# Super Mario All-Stars  Super Mario World http://dbpedia.org/resource/Super_Mario_All-Stars 19
# Lappet-faced vulture http://dbpedia.org/resource/Lappet-faced_vulture 0
# Lappet-faced vulture http://dbpedia.org/resource/Lappet-faced_vulture 0
# Lappet-faced vulture http://dbpedia.org/resource/Lappet-faced_vulture 0
# Lappet-faced vulture http://dbpedia.org/resource/Lappet-faced_vulture 0
# Contender http://dbpedia.org/resource/Contender 0
# Contender http://dbpedia.org/resource/Contender 0
# Contender http://dbpedia.org/resource/The_Contender_(TV_series) 16
# Contender http://dbpedia.org/resource/Contender 0
# Grey-backed fiscal http://dbpedia.org/resource/Grey-backed_fiscal 0
# Grey-backed fiscal http://dbpedia.org/resource/Grey-backed_fiscal 0
# Grey-backed fiscal http://dbpedia.org/resource/Grey-backed_fiscal 0
# Grey-backed fiscal http://dbpedia.org/resource/Grey-backed_fiscal 0
# Heat http://dbpedia.org/resource/Heat 0
# Heat http://dbpedia.org/resource/Heat_stroke 7
# Heat http://dbpedia.org/resource/Heat 0
# Heat http://dbpedia.org/resource/Heat 0
# Pope Linus http://dbpedia.org/resource/Pope_Linus 0
# Pope Linus http://dbpedia.org/resource/Pope_Linus 0
# Pope Linus http://dbpedia.org/resource/Pope_Linus 0
# Pope Linus http://dbpedia.org/resource/Pope_Linus 0
# Broken Bow Lake http://dbpedia.org/resource/Broken_Bow_Lake 0
# Broken Bow Lake http://dbpedia.org/resource/Broken_Bow_Lake 0
# Broken Bow Lake http://dbpedia.org/resource/Broken_Bow_Lake 0
# Broken Bow Lake http://dbpedia.org/resource/Broken_Bow_Lake 0
# TREE SWALLOW http://dbpedia.org/resource/Tree_swallow 0
# TREE SWALLOW http://dbpedia.org/resource/Tree_(command) 9
# TREE SWALLOW http://dbpedia.org/resource/Tree_swallow 0
# The Wild Bunch http://dbpedia.org/resource/The_Wild_Bunch 0
# The Wild Bunch http://dbpedia.org/resource/The_Wild_Bunch 0
# The Wild Bunch http://dbpedia.org/resource/The_Wild_Bunch 0
# The Wild Bunch http://dbpedia.org/resource/The_Wild_Bunch 0
# FIFA 08 http://dbpedia.org/resource/FIFA_08 0
# FIFA 08 http://dbpedia.org/resource/FIFA_08 0
# FIFA 08 http://dbpedia.org/resource/FIFA_08 0
# FIFA 08 http://dbpedia.org/resource/FIFA_08 0
# The Legend of Zelda Ocarina of Time http://dbpedia.org/resource/The_Legend_of_Zelda_Ocarina_of_Time 0
# The Legend of Zelda Ocarina of Time http://dbpedia.org/resource/The_Legend_of_Zelda:_Ocarina_of_Time 1
# The Legend of Zelda Ocarina of Time http://dbpedia.org/resource/The_Legend_of_Zelda 16
# The Legend of Zelda Ocarina of Time http://dbpedia.org/resource/The_Legend_of_Zelda_Ocarina_of_Time 0
# Fellbarrow http://dbpedia.org/resource/Fellbarrow 0
# Fellbarrow http://dbpedia.org/resource/Fellbarrow 0
# Fellbarrow http://dbpedia.org/resource/Fellbarrow 0
# Fellbarrow http://dbpedia.org/resource/Fellbarrow 0
# Sim City http://dbpedia.org/resource/Sim_City 0
# Sim City http://dbpedia.org/resource/SimCity 1
# Sim City http://dbpedia.org/resource/SimCity 1
# Sim City http://dbpedia.org/resource/Sim_City 0
# Asparagus densiflorus http://dbpedia.org/resource/Asparagus_densiflorus 0
# Asparagus densiflorus http://dbpedia.org/resource/Asparagus_densiflorus 0
# Asparagus densiflorus http://dbpedia.org/resource/Asparagus_densiflorus 0
# Asparagus densiflorus http://dbpedia.org/resource/Asparagus_densiflorus 0
# To Be or Not to Be http://dbpedia.org/resource/To_Be_or_Not_to_Be 0
# To Be or Not to Be http://dbpedia.org/resource/To_Be_or_Not_to_Be 0
# To Be or Not to Be http://dbpedia.org/resource/To_Be_(song) 11
# To Be or Not to Be http://dbpedia.org/resource/To_Be_or_Not_to_Be 0
# John of the Cross http://dbpedia.org/resource/John_of_the_Cross 0
# John of the Cross http://dbpedia.org/resource/John_of_the_Cross 0
# John of the Cross http://dbpedia.org/resource/Cross 12
# John of the Cross http://dbpedia.org/resource/John_of_the_Cross 0
# Mark Langston http://dbpedia.org/resource/Mark_Langston 0
# Mark Langston http://dbpedia.org/resource/Mark_Langston 0
# Mark Langston http://dbpedia.org/resource/Mark_Langston 0
# Mark Langston http://dbpedia.org/resource/Mark_Langston 0
# Soldier of Fortune Pay Back http://dbpedia.org/resource/Soldier_of_Fortune_Pay_Back 0
# Soldier of Fortune Pay Back http://dbpedia.org/resource/Soldier_of_Fortune:_Payback 2
# Soldier of Fortune Pay Back http://dbpedia.org/resource/Soldier 20
# Soldier of Fortune Pay Back http://dbpedia.org/resource/Soldier_of_Fortune_Pay_Back 0
# Life as A House http://dbpedia.org/resource/Life_as_a_House 0
# Life as A House http://dbpedia.org/resource/A_House 8
# Life as A House http://dbpedia.org/resource/Life_as_a_House 0
# Brown parrot http://dbpedia.org/resource/Brown_parrot 0
# Brown parrot http://dbpedia.org/resource/Brown_parrotbill 4
# Brown parrot http://dbpedia.org/resource/Parrot 6
# Brown parrot http://dbpedia.org/resource/Brown_parrot 0
# My Cousin Vinny http://dbpedia.org/resource/My_Cousin_Vinny 0
# My Cousin Vinny http://dbpedia.org/resource/My_Cousin_Vinny 0
# My Cousin Vinny http://dbpedia.org/resource/My_Cousin_Vinny 0
# My Cousin Vinny http://dbpedia.org/resource/My_Cousin_Vinny 0
# The Book of Eli http://dbpedia.org/resource/The_Book_of_Eli 0
# The Book of Eli http://dbpedia.org/resource/The_Book_of_Eli 0
# The Book of Eli http://dbpedia.org/resource/Eli_James 12
# The Book of Eli http://dbpedia.org/resource/The_Book_of_Eli 0
# Kaw lake http://dbpedia.org/resource/Kaw_lake 0
# Kaw lake http://dbpedia.org/resource/Kaw_Lake 0
# Kaw lake http://dbpedia.org/resource/Lake 4
# Kaw lake http://dbpedia.org/resource/Kaw_lake 0
# Paulinus of Nola http://dbpedia.org/resource/Paulinus_of_Nola 0
# Paulinus of Nola http://dbpedia.org/resource/Paulinus_of_Nola 0
# Paulinus of Nola http://dbpedia.org/resource/Paulinus_of_Nola 0
# Paulinus of Nola http://dbpedia.org/resource/Paulinus_of_Nola 0
# Three Kings http://dbpedia.org/resource/Three_Kings 0
# Three Kings http://dbpedia.org/resource/Three_Kings_United 7
# Three Kings http://dbpedia.org/resource/Biblical_Magi 12
# Three Kings http://dbpedia.org/resource/Three_Kings 0
# ORCHARD ORIOLE http://dbpedia.org/resource/Orchard_oriole 0
# [SPOTLIGHT] Something went wrong with text: ORCHARD ORIOLE. Returning nothing
# ORCHARD ORIOLE  9999
# ORCHARD ORIOLE http://dbpedia.org/resource/Orchard_oriole 0
# Swingers http://dbpedia.org/resource/Swingers 0
# Swingers http://dbpedia.org/resource/Swinger 1
# [SPOTLIGHT] Something went wrong with text: Swingers. Returning nothing
# Swingers  9999
# Swingers http://dbpedia.org/resource/Swingers 0
# Poa cusickii http://dbpedia.org/resource/Poa_cusickii 0
# Poa cusickii http://dbpedia.org/resource/Poa_cusickii 0
# Poa cusickii http://dbpedia.org/resource/Poa_cusickii 0
# Poa cusickii http://dbpedia.org/resource/Poa_cusickii 0
# Ice Harvest http://dbpedia.org/resource/Ice_Harvest 0
# Ice Harvest http://dbpedia.org/resource/The_Ice_Harvest 4
# Ice Harvest http://dbpedia.org/resource/The_Ice_Harvest 4
# Ice Harvest http://dbpedia.org/resource/Ice_Harvest 0
# Litsea glutinosa http://dbpedia.org/resource/Litsea_glutinosa 0
# Litsea glutinosa http://dbpedia.org/resource/Litsea_glutinosa 0
# Litsea glutinosa http://dbpedia.org/resource/Litsea_glutinosa 0
# Litsea glutinosa http://dbpedia.org/resource/Litsea_glutinosa 0
# Die Sims
# Die Sims  9999
# Die Sims http://dbpedia.org/resource/The_Sims 2
# Die Sims http://dbpedia.org/resource/The_Sims 2
# Donkey Kong Country http://dbpedia.org/resource/Donkey_Kong_Country 0
# Donkey Kong Country http://dbpedia.org/resource/Donkey_Kong_Country 0
# Donkey Kong Country http://dbpedia.org/resource/Donkey_Kong 8
# Donkey Kong Country http://dbpedia.org/resource/Donkey_Kong_Country 0
# Common greenshank http://dbpedia.org/resource/Common_greenshank 0
# Common greenshank http://dbpedia.org/resource/Common_greenshank 0
# Common greenshank http://dbpedia.org/resource/Common_greenshank 0
# Common greenshank http://dbpedia.org/resource/Common_greenshank 0
# Melbourne Airport http://dbpedia.org/resource/Melbourne_Airport 0
# Melbourne Airport http://dbpedia.org/resource/Melbourne_Airport 0
# Melbourne Airport http://dbpedia.org/resource/Melbourne_Airport 0
# Melbourne Airport http://dbpedia.org/resource/Melbourne_Airport 0
# Calf Crag http://dbpedia.org/resource/Calf_Crag 0
# Calf Crag http://dbpedia.org/resource/Calf_Crag 0
# Calf Crag http://dbpedia.org/resource/Calf_Crag 0
# Calf Crag http://dbpedia.org/resource/Calf_Crag 0
# Mexican http://dbpedia.org/resource/Mexican 0
# Mexican http://dbpedia.org/resource/Mexicans 1
# Mexican http://dbpedia.org/resource/Mexico 2
# Mexican http://dbpedia.org/resource/Mexican 0
# Snowy-headed robin-chat http://dbpedia.org/resource/Snowy-crowned_robin-chat 5
# Snowy-headed robin-chat http://dbpedia.org/resource/Robin-chat 13
# Snowy-headed robin-chat http://dbpedia.org/resource/Snowy-crowned_robin-chat 5
# Brown-backed scrub-robin http://dbpedia.org/resource/Brown-backed_scrub-robin 0
# Brown-backed scrub-robin http://dbpedia.org/resource/Brown-backed_scrub_robin 1
# Brown-backed scrub-robin http://dbpedia.org/resource/Brown-backed_scrub_robin 1
# Brown-backed scrub-robin http://dbpedia.org/resource/Brown-backed_scrub-robin 0
# Metroid Prime http://dbpedia.org/resource/Metroid_Prime 0
# Metroid Prime http://dbpedia.org/resource/Metroid_Prime 0
# Metroid Prime http://dbpedia.org/resource/Metroid 6
# Metroid Prime http://dbpedia.org/resource/Metroid_Prime 0
# San Diego Museum of Art http://dbpedia.org/resource/San_Diego_Museum_of_Art 0
# San Diego Museum of Art http://dbpedia.org/resource/San_Diego_Museum_of_Art 0
# San Diego Museum of Art http://dbpedia.org/resource/San_Diego 14
# San Diego Museum of Art http://dbpedia.org/resource/San_Diego_Museum_of_Art 0
# Pitcairn Islands http://dbpedia.org/resource/Pitcairn_Islands 0
# Pitcairn Islands http://dbpedia.org/resource/Pitcairn_Islands 0
# Pitcairn Islands http://dbpedia.org/resource/Pitcairn_Islands 0
# Pitcairn Islands http://dbpedia.org/resource/Pitcairn_Islands 0
# Lingmoor Fell http://dbpedia.org/resource/Lingmoor_Fell 0
# Lingmoor Fell http://dbpedia.org/resource/Lingmoor_Fell 0
# Lingmoor Fell http://dbpedia.org/resource/Lingmoor_Fell 0
# Lingmoor Fell http://dbpedia.org/resource/Lingmoor_Fell 0
# James Camerons Avatar The Game
# James Camerons Avatar The Game  9999
# James Camerons Avatar The Game http://dbpedia.org/resource/Clan_Cameron 22
# James Camerons Avatar The Game http://dbpedia.org/resource/Clan_Cameron 22
# Rattling cisticola http://dbpedia.org/resource/Rattling_cisticola 0
# Rattling cisticola http://dbpedia.org/resource/Rattling_cisticola 0
# Rattling cisticola http://dbpedia.org/resource/Rattling_cisticola 0
# Rattling cisticola http://dbpedia.org/resource/Rattling_cisticola 0
# The Battleship Potemkin http://dbpedia.org/resource/The_Battleship_Potemkin 0
# The Battleship Potemkin http://dbpedia.org/resource/Battleship_Potemkin 4
# The Battleship Potemkin http://dbpedia.org/resource/Battleship_Potemkin 4
# The Battleship Potemkin http://dbpedia.org/resource/The_Battleship_Potemkin 0
# Rijksmuseum http://dbpedia.org/resource/Rijksmuseum 0
# Rijksmuseum http://dbpedia.org/resource/Rijksmuseum 0
# Rijksmuseum http://dbpedia.org/resource/Rijksmuseum 0
# Rijksmuseum http://dbpedia.org/resource/Rijksmuseum 0
# Hennessy http://dbpedia.org/resource/Hennessy 0
# Hennessy http://dbpedia.org/resource/Hennessy 0
# Hennessy http://dbpedia.org/resource/Hennessy 0
# Hennessy http://dbpedia.org/resource/Hennessy 0
# Andropogon hallii http://dbpedia.org/resource/Andropogon_hallii 0
# Andropogon hallii http://dbpedia.org/resource/Andropogon_hallii 0
# Andropogon hallii http://dbpedia.org/resource/Andropogon_hallii 0
# Andropogon hallii http://dbpedia.org/resource/Andropogon_hallii 0
# Das Boot http://dbpedia.org/resource/Das_Boot 0
# Das Boot http://dbpedia.org/resource/Das_Boot 0
# Das Boot http://dbpedia.org/resource/Das_Boot 0
# Das Boot http://dbpedia.org/resource/Das_Boot 0
# Star Wars Clone Wars http://dbpedia.org/resource/Star_Wars_Clone_Wars 0
# Star Wars Clone Wars http://dbpedia.org/resource/Clone_Wars_(Star_Wars) 11
# Star Wars Clone Wars http://dbpedia.org/resource/Star_Wars 11
# Star Wars Clone Wars http://dbpedia.org/resource/Star_Wars_Clone_Wars 0
# Bosnia and Herzegovina http://dbpedia.org/resource/Bosnia_and_Herzegovina 0
# Bosnia and Herzegovina http://dbpedia.org/resource/Bosnia_and_Herzegovina 0
# Bosnia and Herzegovina http://dbpedia.org/resource/Bosnia_and_Herzegovina 0
# Bosnia and Herzegovina http://dbpedia.org/resource/Bosnia_and_Herzegovina 0
# Gran Turismo 3 A-spec http://dbpedia.org/resource/Gran_Turismo_3_A-spec 0
# Gran Turismo 3 A-spec http://dbpedia.org/resource/Gran_Turismo_3:_A-Spec 1
# Gran Turismo 3 A-spec http://dbpedia.org/resource/Grand_tourer 14
# Gran Turismo 3 A-spec http://dbpedia.org/resource/Gran_Turismo_3_A-spec 0
# Dead Poets Society http://dbpedia.org/resource/Dead_Poets_Society 0
# Dead Poets Society http://dbpedia.org/resource/Dead_Poets_Society 0
# Dead Poets Society http://dbpedia.org/resource/Dead_Poets_Society 0
# Dead Poets Society http://dbpedia.org/resource/Dead_Poets_Society 0
# Tootsie http://dbpedia.org/resource/Tootsie 0
# Tootsie http://dbpedia.org/resource/Tootsie 0
# Tootsie http://dbpedia.org/resource/Tootsie 0
# Tootsie http://dbpedia.org/resource/Tootsie 0
# Black-billed wood-dove http://dbpedia.org/resource/Black-billed_wood-dove 0
# Black-billed wood-dove http://dbpedia.org/resource/Black-billed_wood_dove 1
# Black-billed wood-dove http://dbpedia.org/resource/Black-billed_wood_dove 1
# Black-billed wood-dove http://dbpedia.org/resource/Black-billed_wood-dove 0
# Legend of Zelda Majoras MaskThe Legend of Zelda Majoras Mask
# Legend of Zelda Majoras MaskThe Legend of Zelda Majoras Mask  9999
# Legend of Zelda Majoras MaskThe Legend of Zelda Majoras Mask http://dbpedia.org/resource/The_Legend_of_Zelda 41
# Legend of Zelda Majoras MaskThe Legend of Zelda Majoras Mask http://dbpedia.org/resource/The_Legend_of_Zelda 41
# EASTERN CHIPMUNK http://dbpedia.org/resource/Eastern_chipmunk 0
# EASTERN CHIPMUNK http://dbpedia.org/resource/Eastern_Time_Zone 8
# EASTERN CHIPMUNK http://dbpedia.org/resource/Eastern_chipmunk 0
# Pope Innocent I http://dbpedia.org/resource/Pope_Innocent_I 0
# Pope Innocent I http://dbpedia.org/resource/Pope_Innocent_I 0
# Pope Innocent I http://dbpedia.org/resource/Pope_Innocent_I 0
# Pope Innocent I http://dbpedia.org/resource/Pope_Innocent_I 0
# Archives of Internal Medicine http://dbpedia.org/resource/Archives_of_Internal_Medicine 0
# Archives of Internal Medicine http://dbpedia.org/resource/JAMA_Internal_Medicine 11
# Archives of Internal Medicine http://dbpedia.org/resource/Internal_medicine 12
# Archives of Internal Medicine http://dbpedia.org/resource/Archives_of_Internal_Medicine 0
# St Helena Pound http://dbpedia.org/resource/Saint_Helena_pound 3
# St Helena Pound http://dbpedia.org/resource/Saint_Helena 9
# St Helena Pound http://dbpedia.org/resource/Saint_Helena_pound 3
# Thunderbird Lake
# Thunderbird Lake  9999
# Thunderbird Lake http://dbpedia.org/resource/Lake 12
# Thunderbird Lake http://dbpedia.org/resource/Lake 12
# Harlan County Lake http://dbpedia.org/resource/Harlan_County_Lake 0
# Harlan County Lake http://dbpedia.org/resource/Harlan_County_Reservoir 8
# Harlan County Lake http://dbpedia.org/resource/County 12
# Harlan County Lake http://dbpedia.org/resource/Harlan_County_Lake 0
# Godfather The http://dbpedia.org/resource/Speak_Softly,_Love 15
# Godfather The http://dbpedia.org/resource/The_Godfather 8
# Godfather The http://dbpedia.org/resource/The_Godfather 8
# Midnight Club 2 http://dbpedia.org/resource/Midnight_Club_2 0
# Midnight Club 2 http://dbpedia.org/resource/Midnight_Club_II 2
# Midnight Club 2 http://dbpedia.org/resource/Midnight 7
# Midnight Club 2 http://dbpedia.org/resource/Midnight_Club_2 0
# Acacia longifolia http://dbpedia.org/resource/Acacia_longifolia 0
# Acacia longifolia http://dbpedia.org/resource/Acacia_longifolia 0
# Acacia longifolia http://dbpedia.org/resource/Acacia 11
# Acacia longifolia http://dbpedia.org/resource/Acacia_longifolia 0
# FaceOff http://dbpedia.org/resource/FaceOff 0
# FaceOff http://dbpedia.org/resource/Face_Off 1
# [SPOTLIGHT] Something went wrong with text: FaceOff. Returning nothing
# FaceOff  9999
# FaceOff http://dbpedia.org/resource/FaceOff 0
# SingStar Pop Hits http://dbpedia.org/resource/SingStar_Pop_Hits 0
# SingStar Pop Hits http://dbpedia.org/resource/List_of_songs_in_SingStar_games_(PlayStation_2) 36
# [SPOTLIGHT] Something went wrong with text: SingStar Pop Hits. Returning nothing
# SingStar Pop Hits  9999
# SingStar Pop Hits http://dbpedia.org/resource/SingStar_Pop_Hits 0
# SEGA Rally Revo http://dbpedia.org/resource/SEGA_Rally_Revo 0
# SEGA Rally Revo http://dbpedia.org/resource/Sega_Rally_Revo 0
# SEGA Rally Revo http://dbpedia.org/resource/Sega_Rally_Revo 0
# SEGA Rally Revo http://dbpedia.org/resource/SEGA_Rally_Revo 0
# Namibia http://dbpedia.org/resource/Namibia 0
# Namibia http://dbpedia.org/resource/Namibia 0
# Namibia http://dbpedia.org/resource/Namibia 0
# Namibia http://dbpedia.org/resource/Namibia 0
# World Of Warcraft Wrath Of The Lich King - Addon
# World Of Warcraft Wrath Of The Lich King - Addon  9999
# World Of Warcraft Wrath Of The Lich King - Addon http://dbpedia.org/resource/World_of_Warcraft:_Wrath_of_the_Lich_King 9
# World Of Warcraft Wrath Of The Lich King - Addon http://dbpedia.org/resource/World_of_Warcraft:_Wrath_of_the_Lich_King 9
# Abraham the Syrian http://dbpedia.org/resource/Abraham_the_Syrian 0
# Abraham the Syrian http://dbpedia.org/resource/Pope_Abraham_of_Alexandria 15
# Abraham the Syrian http://dbpedia.org/resource/Abraham 11
# Abraham the Syrian http://dbpedia.org/resource/Abraham_the_Syrian 0
# Call of Duty 2 http://dbpedia.org/resource/Call_of_Duty_2 0
# Call of Duty 2 http://dbpedia.org/resource/Call_of_Duty_2 0
# Call of Duty 2 http://dbpedia.org/resource/Duty 10
# Call of Duty 2 http://dbpedia.org/resource/Call_of_Duty_2 0
# The Good the Bad and the Ugly http://dbpedia.org/resource/The_Good_the_Bad_and_the_Ugly 0
# The Good the Bad and the Ugly http://dbpedia.org/resource/The_Good,_the_Bad_and_the_Ugly 1
# The Good the Bad and the Ugly http://dbpedia.org/resource/Form_of_the_Good 22
# The Good the Bad and the Ugly http://dbpedia.org/resource/The_Good_the_Bad_and_the_Ugly 0
# Leymus innovatus http://dbpedia.org/resource/Leymus_innovatus 0
# Leymus innovatus http://dbpedia.org/resource/Leymus_innovatus 0
# Leymus innovatus http://dbpedia.org/resource/Leymus_innovatus 0
# Leymus innovatus http://dbpedia.org/resource/Leymus_innovatus 0
# Muhlenbergia cuspidata http://dbpedia.org/resource/Muhlenbergia_cuspidata 0
# Muhlenbergia cuspidata http://dbpedia.org/resource/Muhlenbergia_cuspidata 0
# Muhlenbergia cuspidata http://dbpedia.org/resource/Muhlenbergia 10
# Muhlenbergia cuspidata http://dbpedia.org/resource/Muhlenbergia_cuspidata 0
# BROWN CREEPER http://dbpedia.org/resource/Brown_creeper 0
# [SPOTLIGHT] Something went wrong with text: BROWN CREEPER. Returning nothing
# BROWN CREEPER  9999
# BROWN CREEPER http://dbpedia.org/resource/Brown_creeper 0
# Alum Creek Lake Also includes Delaware Lake OH and Hoover Reservoir OH
# Alum Creek Lake Also includes Delaware Lake OH and Hoover Reservoir OH  9999
# Alum Creek Lake Also includes Delaware Lake OH and Hoover Reservoir OH http://dbpedia.org/resource/Alum_Creek_Lake 55
# Alum Creek Lake Also includes Delaware Lake OH and Hoover Reservoir OH http://dbpedia.org/resource/Alum_Creek_Lake 55
# Wrestler The
# Wrestler The  9999
# Wrestler The http://dbpedia.org/resource/Wrestling 6
# Wrestler The http://dbpedia.org/resource/Wrestling 6
# DArbonne Lake
# DArbonne Lake  9999
# DArbonne Lake http://dbpedia.org/resource/Lake 9
# DArbonne Lake http://dbpedia.org/resource/Lake 9
# Austria http://dbpedia.org/resource/Austria 0
# Austria http://dbpedia.org/resource/Austria 0
# Austria http://dbpedia.org/resource/Austria 0
# Austria http://dbpedia.org/resource/Austria 0
# Tommy http://dbpedia.org/resource/Tommy 0
# Tommy http://dbpedia.org/resource/Tommy_James 6
# [SPOTLIGHT] Something went wrong with text: Tommy. Returning nothing
# Tommy  9999
# Tommy http://dbpedia.org/resource/Tommy 0
# Cestrum parqui http://dbpedia.org/resource/Cestrum_parqui 0
# Cestrum parqui http://dbpedia.org/resource/Cestrum_parqui 0
# Cestrum parqui http://dbpedia.org/resource/Cestrum 7
# Cestrum parqui http://dbpedia.org/resource/Cestrum_parqui 0
# Resistance Fall of Man http://dbpedia.org/resource/Resistance:_Fall_of_Man 1
# Resistance Fall of Man http://dbpedia.org/resource/Fall_of_man 11
# Resistance Fall of Man http://dbpedia.org/resource/Resistance:_Fall_of_Man 1
# Ziziphus jujuba http://dbpedia.org/resource/Ziziphus_jujuba 0
# Ziziphus jujuba http://dbpedia.org/resource/Jujube 10
# Ziziphus jujuba http://dbpedia.org/resource/Ziziphus 7
# Ziziphus jujuba http://dbpedia.org/resource/Ziziphus_jujuba 0
# Luxembourg http://dbpedia.org/resource/Luxembourg 0
# Luxembourg http://dbpedia.org/resource/Luxembourg 0
# Luxembourg http://dbpedia.org/resource/Luxembourg 0
# Luxembourg http://dbpedia.org/resource/Luxembourg 0
# Ikiru http://dbpedia.org/resource/Ikiru 0
# Ikiru http://dbpedia.org/resource/Ikiru 0
# Ikiru http://dbpedia.org/resource/Ikiru 0
# Ikiru http://dbpedia.org/resource/Ikiru 0
# Virgin Islands http://dbpedia.org/resource/Virgin_Islands 0
# Virgin Islands http://dbpedia.org/resource/Virgin_Islands 0
# Virgin Islands http://dbpedia.org/resource/Virgin_Islands 0
# Virgin Islands http://dbpedia.org/resource/Virgin_Islands 0
# Ordinary People http://dbpedia.org/resource/Ordinary_People 0
# Ordinary People http://dbpedia.org/resource/Ordinary_People 0
# Ordinary People http://dbpedia.org/resource/Ordinary_People 0
# Ordinary People http://dbpedia.org/resource/Ordinary_People 0
# Texana Lake http://dbpedia.org/resource/Texana_Lake 0
# Texana Lake http://dbpedia.org/resource/Lake_Texana 10
# Texana Lake http://dbpedia.org/resource/Lake 7
# Texana Lake http://dbpedia.org/resource/Texana_Lake 0
# Carex lenticularis var dolia
# Carex lenticularis var dolia  9999
# Carex lenticularis var dolia http://dbpedia.org/resource/Carex 23
# Carex lenticularis var dolia http://dbpedia.org/resource/Carex 23
# Chrysobalanus icaco http://dbpedia.org/resource/Chrysobalanus_icaco 0
# Chrysobalanus icaco http://dbpedia.org/resource/Chrysobalanus_icaco 0
# Chrysobalanus icaco http://dbpedia.org/resource/Chrysobalanus 6
# Chrysobalanus icaco http://dbpedia.org/resource/Chrysobalanus_icaco 0
# NCAA Football 2004 http://dbpedia.org/resource/NCAA_Football_2004 0
# NCAA Football 2004 http://dbpedia.org/resource/NCAA_Football_2004 0
# NCAA Football 2004 http://dbpedia.org/resource/NCAA_Football_2004 0
# NCAA Football 2004 http://dbpedia.org/resource/NCAA_Football_2004 0
# New England Journal of Medicine http://dbpedia.org/resource/New_England_Journal_of_Medicine 0
# New England Journal of Medicine http://dbpedia.org/resource/The_New_England_Journal_of_Medicine 4
# New England Journal of Medicine http://dbpedia.org/resource/New_England 20
# New England Journal of Medicine http://dbpedia.org/resource/New_England_Journal_of_Medicine 0
# Jackie Robinson http://dbpedia.org/resource/Jackie_Robinson 0
# Jackie Robinson http://dbpedia.org/resource/Jackie_Robinson 0
# Jackie Robinson http://dbpedia.org/resource/Jackie_Robinson 0
# Jackie Robinson http://dbpedia.org/resource/Jackie_Robinson 0
# MX vs ATV Untamed http://dbpedia.org/resource/MX_vs_ATV_Untamed 0
# MX vs ATV Untamed http://dbpedia.org/resource/MX_vs._ATV 9
# MX vs ATV Untamed http://dbpedia.org/resource/Associated_Television 18
# MX vs ATV Untamed http://dbpedia.org/resource/MX_vs_ATV_Untamed 0
# Toyota Motor http://dbpedia.org/resource/Toyota_Motor 0
# Toyota Motor http://dbpedia.org/resource/Toyota 6
# Toyota Motor http://dbpedia.org/resource/Toyota 6
# Toyota Motor http://dbpedia.org/resource/Toyota_Motor 0
# Metro 2033 http://dbpedia.org/resource/Metro_2033 0
# Metro 2033 http://dbpedia.org/resource/Metro_2033 0
# Metro 2033 http://dbpedia.org/resource/Metro_2033 0
# Metro 2033 http://dbpedia.org/resource/Metro_2033 0
# Civil Action A
# Civil Action A  9999
# Civil Action A http://dbpedia.org/resource/Lawsuit 12
# Civil Action A http://dbpedia.org/resource/Lawsuit 12
# COAL SKINK http://dbpedia.org/resource/Plestiodon_anthracinus 18
# [SPOTLIGHT] Something went wrong with text: COAL SKINK. Returning nothing
# COAL SKINK  9999
# COAL SKINK http://dbpedia.org/resource/Plestiodon_anthracinus 18
# Frasier http://dbpedia.org/resource/Frasier 0
# Frasier http://dbpedia.org/resource/Frasier_(season_1) 11
# Frasier http://dbpedia.org/resource/Frasier 0
# Frasier http://dbpedia.org/resource/Frasier 0
# Calamus spp
# Calamus spp  9999
# Calamus spp http://dbpedia.org/resource/Acorus_calamus 11
# Calamus spp http://dbpedia.org/resource/Acorus_calamus 11
# The Untouchables http://dbpedia.org/resource/The_Untouchables 0
# The Untouchables http://dbpedia.org/resource/Untouchable 5
# The Untouchables http://dbpedia.org/resource/Deuce_'n_Domino 15
# The Untouchables http://dbpedia.org/resource/The_Untouchables 0
# Call of Duty 4 Modern Warfare http://dbpedia.org/resource/Call_of_Duty_4_Modern_Warfare 0
# Call of Duty 4 Modern Warfare http://dbpedia.org/resource/Call_of_Duty_4:_Modern_Warfare 1
# Call of Duty 4 Modern Warfare http://dbpedia.org/resource/The_San_Francisco_Call 25
# Call of Duty 4 Modern Warfare http://dbpedia.org/resource/Call_of_Duty_4_Modern_Warfare 0
# Nauru http://dbpedia.org/resource/Nauru 0
# Nauru http://dbpedia.org/resource/Nauru 0
# Nauru http://dbpedia.org/resource/Nauru 0
# Nauru http://dbpedia.org/resource/Nauru 0
# Be Kind Rewind http://dbpedia.org/resource/Be_Kind_Rewind 0
# Be Kind Rewind http://dbpedia.org/resource/Be_Kind_Rewind 0
# Be Kind Rewind http://dbpedia.org/resource/Be_Kind_Rewind 0
# Be Kind Rewind http://dbpedia.org/resource/Be_Kind_Rewind 0
# Luxembourg http://dbpedia.org/resource/Luxembourg 0
# Luxembourg http://dbpedia.org/resource/Luxembourg 0
# Luxembourg http://dbpedia.org/resource/Luxembourg 0
# Luxembourg http://dbpedia.org/resource/Luxembourg 0
# Georg Friedrich Hndel
# Georg Friedrich Hndel  9999
# Georg Friedrich Hndel http://dbpedia.org/resource/Georg_von_Trapp 14
# Georg Friedrich Hndel http://dbpedia.org/resource/Georg_von_Trapp 14
# Ulex europaeus http://dbpedia.org/resource/Ulex_europaeus 0
# Ulex europaeus http://dbpedia.org/resource/Ulex_europaeus 0
# Ulex europaeus http://dbpedia.org/resource/Ulex_europaeus 0
# Ulex europaeus http://dbpedia.org/resource/Ulex_europaeus 0
# The Club http://dbpedia.org/resource/The_Club 0
# The Club http://dbpedia.org/resource/The_Club 0
# The Club http://dbpedia.org/resource/Persepolis_F.C. 13
# The Club http://dbpedia.org/resource/The_Club 0
# Singer Museum http://dbpedia.org/resource/Singer_Museum 0
# Singer Museum http://dbpedia.org/resource/Singer_Laren 5
# Singer Museum http://dbpedia.org/resource/Singer_Laren 5
# Singer Museum http://dbpedia.org/resource/Singer_Museum 0
# City Lights http://dbpedia.org/resource/City_Lights 0
# City Lights http://dbpedia.org/resource/City_Lights 0
# City Lights http://dbpedia.org/resource/City_Lights 0
# City Lights http://dbpedia.org/resource/City_Lights 0
# The Seven Samurai http://dbpedia.org/resource/The_Seven_Samurai 0
# The Seven Samurai http://dbpedia.org/resource/Seven_Samurai 4
# The Seven Samurai http://dbpedia.org/resource/Seven_Samurai 4
# The Seven Samurai http://dbpedia.org/resource/The_Seven_Samurai 0
# Resistance 2 http://dbpedia.org/resource/Resistance_2 0
# Resistance 2 http://dbpedia.org/resource/Resistance_2 0
# Resistance 2 http://dbpedia.org/resource/Resistance_2 0
# Resistance 2 http://dbpedia.org/resource/Resistance_2 0
# Eddie Guerrero http://dbpedia.org/resource/Eddie_Guerrero 0
# Eddie Guerrero http://dbpedia.org/resource/Eddie_Guerrero 0
# Eddie Guerrero http://dbpedia.org/resource/Eddie_Guerrero 0
# Eddie Guerrero http://dbpedia.org/resource/Eddie_Guerrero 0
# Pope Anicetus http://dbpedia.org/resource/Pope_Anicetus 0
# Pope Anicetus http://dbpedia.org/resource/Pope_Anicetus 0
# Pope Anicetus http://dbpedia.org/resource/Pope_Anicetus 0
# Pope Anicetus http://dbpedia.org/resource/Pope_Anicetus 0
# Columbanus http://dbpedia.org/resource/Columbanus 0
# Columbanus http://dbpedia.org/resource/Columbanus 0
# Columbanus http://dbpedia.org/resource/Columbanus 0
# Columbanus http://dbpedia.org/resource/Columbanus 0
# Finland http://dbpedia.org/resource/Finland 0
# Finland http://dbpedia.org/resource/Finland 0
# Finland http://dbpedia.org/resource/Finland 0
# Finland http://dbpedia.org/resource/Finland 0
# Black-shouldered kite http://dbpedia.org/resource/Black-shouldered_kite 0
# Black-shouldered kite http://dbpedia.org/resource/Black-shouldered_kite 0
# Black-shouldered kite http://dbpedia.org/resource/Black-shouldered_kite 0
# Black-shouldered kite http://dbpedia.org/resource/Black-shouldered_kite 0
# Pope Of Greenwich Village
# Pope Of Greenwich Village  9999
# Pope Of Greenwich Village http://dbpedia.org/resource/Greenwich_Village 8
# Pope Of Greenwich Village http://dbpedia.org/resource/Greenwich_Village 8
# EASTERN TOWHEE http://dbpedia.org/resource/Eastern_towhee 0
# EASTERN TOWHEE http://dbpedia.org/resource/Eastern_Time_Zone 7
# EASTERN TOWHEE http://dbpedia.org/resource/Eastern_towhee 0
# Rashmon
# Rashmon  9999
# [SPOTLIGHT] Something went wrong with text: Rashmon. Returning nothing
# Rashmon  9999
# Rashmon  9999
# Panama http://dbpedia.org/resource/Panama 0
# Panama http://dbpedia.org/resource/Panama 0
# Panama http://dbpedia.org/resource/Panama 0
# Panama http://dbpedia.org/resource/Panama 0
# Holland Museum http://dbpedia.org/resource/Holland_Museum 0
# Holland Museum http://dbpedia.org/resource/Holland_Museum 0
# Holland Museum http://dbpedia.org/resource/Holland_Museum 0
# Holland Museum http://dbpedia.org/resource/Holland_Museum 0
# Grike http://dbpedia.org/resource/Grike 0
# Grike http://dbpedia.org/resource/Grike 0
# Grike http://dbpedia.org/resource/Grike_(Lake_District) 16
# Grike http://dbpedia.org/resource/Grike 0
# Civilization http://dbpedia.org/resource/Civilization 0
# Civilization http://dbpedia.org/resource/Civilization 0
# Civilization http://dbpedia.org/resource/Civilization 0
# Civilization http://dbpedia.org/resource/Civilization 0
# Grand Theft Auto 2 http://dbpedia.org/resource/Grand_Theft_Auto_2 0
# Grand Theft Auto 2 http://dbpedia.org/resource/Grand_Theft_Auto_2 0
# Grand Theft Auto 2 http://dbpedia.org/resource/Grand_Theft_Auto_2 0
# Grand Theft Auto 2 http://dbpedia.org/resource/Grand_Theft_Auto_2 0
# The Proposal http://dbpedia.org/resource/The_Proposal 0
# The Proposal http://dbpedia.org/resource/The_Proposal_(novel) 8
# The Proposal http://dbpedia.org/resource/A_Marriage_Proposal 9
# The Proposal http://dbpedia.org/resource/The_Proposal 0
# CFP Franc http://dbpedia.org/resource/CFP_Franc 0
# CFP Franc http://dbpedia.org/resource/CFP_franc 0
# CFP Franc http://dbpedia.org/resource/CFP_franc 0
# CFP Franc http://dbpedia.org/resource/CFP_Franc 0
# Tuvalu http://dbpedia.org/resource/Tuvalu 0
# Tuvalu http://dbpedia.org/resource/Tuvalu 0
# Tuvalu http://dbpedia.org/resource/Tuvalu 0
# Tuvalu http://dbpedia.org/resource/Tuvalu 0
# FIFA 11 http://dbpedia.org/resource/FIFA_11 0
# FIFA 11 http://dbpedia.org/resource/FIFA_11 0
# FIFA 11 http://dbpedia.org/resource/FIFA_11 0
# FIFA 11 http://dbpedia.org/resource/FIFA_11 0
# Max Payne http://dbpedia.org/resource/Max_Payne 0
# Max Payne http://dbpedia.org/resource/Max_Payne 0
# Max Payne http://dbpedia.org/resource/Max_Payne 0
# Max Payne http://dbpedia.org/resource/Max_Payne 0
# Cabaniss bunting
# Cabaniss bunting  9999
# Cabaniss bunting http://dbpedia.org/resource/Sadie_Heath_Cabaniss 16
# Cabaniss bunting http://dbpedia.org/resource/Sadie_Heath_Cabaniss 16
# Lake Maggiore http://dbpedia.org/resource/Lake_Maggiore 0
# Lake Maggiore http://dbpedia.org/resource/Lake_Maggiore 0
# Lake Maggiore http://dbpedia.org/resource/Lake_Maggiore 0
# Lake Maggiore http://dbpedia.org/resource/Lake_Maggiore 0
# Gaylord Perry http://dbpedia.org/resource/Gaylord_Perry 0
# Gaylord Perry http://dbpedia.org/resource/Gaylord_Perry 0
# Gaylord Perry http://dbpedia.org/resource/Gaylord_Perry 0
# Gaylord Perry http://dbpedia.org/resource/Gaylord_Perry 0
# Bouteloua eriopoda http://dbpedia.org/resource/Bouteloua_eriopoda 0
# Bouteloua eriopoda http://dbpedia.org/resource/Bouteloua_eriopoda 0
# Bouteloua eriopoda http://dbpedia.org/resource/Bouteloua 9
# Bouteloua eriopoda http://dbpedia.org/resource/Bouteloua_eriopoda 0
# Tom Jones http://dbpedia.org/resource/Tom_Jones 0
# Tom Jones http://dbpedia.org/resource/Tom_Jones 0
# Tom Jones http://dbpedia.org/resource/Tom_Jones_(singer) 9
# Tom Jones http://dbpedia.org/resource/Tom_Jones 0
# Trinidad and Tobago http://dbpedia.org/resource/Trinidad_and_Tobago 0
# Trinidad and Tobago http://dbpedia.org/resource/Trinidad_and_Tobago 0
# Trinidad and Tobago http://dbpedia.org/resource/Trinidad 11
# Trinidad and Tobago http://dbpedia.org/resource/Trinidad_and_Tobago 0
# Rio Bravo http://dbpedia.org/resource/Rio_Bravo 0
# Rio Bravo http://dbpedia.org/resource/Rio_Grande 4
# Rio Bravo http://dbpedia.org/resource/Rio_Grande 4
# Rio Bravo http://dbpedia.org/resource/Rio_Bravo 0
# The Lord of the Rings The Fellowship of the Ring
# The Lord of the Rings The Fellowship of the Ring  9999
# The Lord of the Rings The Fellowship of the Ring http://dbpedia.org/resource/The_Fellowship_(Christian_organization) 37
# The Lord of the Rings The Fellowship of the Ring http://dbpedia.org/resource/The_Fellowship_(Christian_organization) 37
# Ferris Buellers Day Off http://dbpedia.org/resource/Ferris_Buellers_Day_Off 0
# Ferris Buellers Day Off http://dbpedia.org/resource/Ferris_Bueller's_Day_Off 1
# Ferris Buellers Day Off http://dbpedia.org/resource/Off_(video_game) 19
# Ferris Buellers Day Off http://dbpedia.org/resource/Ferris_Buellers_Day_Off 0
# Singapore http://dbpedia.org/resource/Singapore 0
# Singapore http://dbpedia.org/resource/Singapore 0
# Singapore http://dbpedia.org/resource/Singapore 0
# Singapore http://dbpedia.org/resource/Singapore 0
# REDBACK SALAMANDER http://dbpedia.org/resource/Red-backed_salamander 3
# [SPOTLIGHT] Something went wrong with text: REDBACK SALAMANDER. Returning nothing
# REDBACK SALAMANDER  9999
# REDBACK SALAMANDER http://dbpedia.org/resource/Red-backed_salamander 3
# Legendary http://dbpedia.org/resource/Legendary 0
# Legendary http://dbpedia.org/resource/Legendary_saga 5
# Legendary http://dbpedia.org/resource/Legendary_Entertainment 14
# Legendary http://dbpedia.org/resource/Legendary 0
# Maesopsis eminii http://dbpedia.org/resource/Maesopsis_eminii 0
# Maesopsis eminii http://dbpedia.org/resource/Maesopsis 7
# Maesopsis eminii http://dbpedia.org/resource/Maesopsis 7
# Maesopsis eminii http://dbpedia.org/resource/Maesopsis_eminii 0
# Passiflora coccinea http://dbpedia.org/resource/Passiflora_coccinea 0
# Passiflora coccinea http://dbpedia.org/resource/Passiflora_coccinea 0
# Passiflora coccinea http://dbpedia.org/resource/Passiflora 9
# Passiflora coccinea http://dbpedia.org/resource/Passiflora_coccinea 0
# Hairy-breasted barbet http://dbpedia.org/resource/Hairy-breasted_barbet 0
# Hairy-breasted barbet http://dbpedia.org/resource/Hairy-breasted_barbet 0
# Hairy-breasted barbet http://dbpedia.org/resource/Asian_barbet 12
# Hairy-breasted barbet http://dbpedia.org/resource/Hairy-breasted_barbet 0
# Once Upon a Time in the West http://dbpedia.org/resource/Once_Upon_a_Time_in_the_West 0
# Once Upon a Time in the West http://dbpedia.org/resource/Once_Upon_a_Time_in_the_West 0
# Once Upon a Time in the West http://dbpedia.org/resource/Once_(film) 22
# Once Upon a Time in the West http://dbpedia.org/resource/Once_Upon_a_Time_in_the_West 0
# Hypericum canariense http://dbpedia.org/resource/Hypericum_canariense 0
# Hypericum canariense http://dbpedia.org/resource/Hypericum_canariense 0
# Hypericum canariense http://dbpedia.org/resource/Hypericum_canariense 0
# Hypericum canariense http://dbpedia.org/resource/Hypericum_canariense 0
# Indiana Jones And The Last Crusade http://dbpedia.org/resource/Indiana_Jones_And_The_Last_Crusade 0
# Indiana Jones And The Last Crusade http://dbpedia.org/resource/Indiana_Jones_and_the_Last_Crusade 0
# Indiana Jones And The Last Crusade http://dbpedia.org/resource/Indiana_Jones_and_the_Last_Crusade 0
# Indiana Jones And The Last Crusade http://dbpedia.org/resource/Indiana_Jones_And_The_Last_Crusade 0
# Pope Felix II http://dbpedia.org/resource/Pope_Felix_II 0
# Pope Felix II http://dbpedia.org/resource/Pope_Felix_III 1
# Pope Felix II http://dbpedia.org/resource/World_War_II 9
# Pope Felix II http://dbpedia.org/resource/Pope_Felix_II 0
# Residenzgalerie http://dbpedia.org/resource/Residenzgalerie 0
# Residenzgalerie http://dbpedia.org/resource/Residenzgalerie 0
# Residenzgalerie http://dbpedia.org/resource/Residenzgalerie 0
# Residenzgalerie http://dbpedia.org/resource/Residenzgalerie 0
# East Caribbean Dollar http://dbpedia.org/resource/East_Caribbean_Dollar 0
# East Caribbean Dollar http://dbpedia.org/resource/Eastern_Caribbean_dollar 3
# East Caribbean Dollar http://dbpedia.org/resource/Eastern_Caribbean_dollar 3
# East Caribbean Dollar http://dbpedia.org/resource/East_Caribbean_Dollar 0
# Alice in Wonderland http://dbpedia.org/resource/Alice_in_Wonderland 0
# Alice in Wonderland http://dbpedia.org/resource/Alice_in_Wonderland_syndrome 9
# Alice in Wonderland http://dbpedia.org/resource/Alice_and_Bob 11
# Alice in Wonderland http://dbpedia.org/resource/Alice_in_Wonderland 0
# Carl Friedrich Gauss http://dbpedia.org/resource/Carl_Friedrich_Gauss 0
# Carl Friedrich Gauss http://dbpedia.org/resource/Carl_Friedrich_Gauss 0
# Carl Friedrich Gauss http://dbpedia.org/resource/Carl_Friedrich_Gauss 0
# Carl Friedrich Gauss http://dbpedia.org/resource/Carl_Friedrich_Gauss 0
# Romania http://dbpedia.org/resource/Romania 0
# Romania http://dbpedia.org/resource/Romania 0
# Romania http://dbpedia.org/resource/Romania 0
# Romania http://dbpedia.org/resource/Romania 0
# East Caribbean Dollar http://dbpedia.org/resource/East_Caribbean_Dollar 0
# East Caribbean Dollar http://dbpedia.org/resource/Eastern_Caribbean_dollar 3
# East Caribbean Dollar http://dbpedia.org/resource/Eastern_Caribbean_dollar 3
# East Caribbean Dollar http://dbpedia.org/resource/East_Caribbean_Dollar 0
# Rosss turaco
# Rosss turaco  9999
# Rosss turaco http://dbpedia.org/resource/Turaco 6
# Rosss turaco http://dbpedia.org/resource/Turaco 6
# Sprengel Museum http://dbpedia.org/resource/Sprengel_Museum 0
# Sprengel Museum http://dbpedia.org/resource/Sprengel_Museum 0
# Sprengel Museum http://dbpedia.org/resource/Sprengel_Museum 0
# Sprengel Museum http://dbpedia.org/resource/Sprengel_Museum 0
# Resonance of Fate http://dbpedia.org/resource/Resonance_of_Fate 0
# Resonance of Fate http://dbpedia.org/resource/Resonance_of_Fate 0
# Resonance of Fate http://dbpedia.org/resource/Resonance 8
# Resonance of Fate http://dbpedia.org/resource/Resonance_of_Fate 0
# SBK X http://dbpedia.org/resource/SBK_X:_Superbike_World_Championship 30
# SBK X http://dbpedia.org/resource/SBK_Records 7
# SBK X http://dbpedia.org/resource/SBK_Records 7
# The Adjustment Bureau http://dbpedia.org/resource/The_Adjustment_Bureau 0
# The Adjustment Bureau http://dbpedia.org/resource/The_Adjustment_Bureau 0
# The Adjustment Bureau http://dbpedia.org/resource/The_Adjustment_Bureau 0
# The Adjustment Bureau http://dbpedia.org/resource/The_Adjustment_Bureau 0
# Ontariosee
# Ontariosee  9999
# [SPOTLIGHT] Something went wrong with text: Ontariosee. Returning nothing
# Ontariosee  9999
# Ontariosee  9999
# Yellow-bellied wattle-eye http://dbpedia.org/resource/Yellow-bellied_wattle-eye 0
# Yellow-bellied wattle-eye http://dbpedia.org/resource/Yellow-bellied_wattle-eye 0
# Yellow-bellied wattle-eye http://dbpedia.org/resource/Yellow-bellied_wattle-eye 0
# Yellow-bellied wattle-eye http://dbpedia.org/resource/Yellow-bellied_wattle-eye 0
# Willie Stargell http://dbpedia.org/resource/Willie_Stargell 0
# Willie Stargell http://dbpedia.org/resource/Willie_Stargell 0
# Willie Stargell http://dbpedia.org/resource/Willie_Stargell 0
# Willie Stargell http://dbpedia.org/resource/Willie_Stargell 0
# Aristida purpurea http://dbpedia.org/resource/Aristida_purpurea 0
# Aristida purpurea http://dbpedia.org/resource/Aristida_purpurea 0
# Aristida purpurea http://dbpedia.org/resource/Aristida_purpurea 0
# Aristida purpurea http://dbpedia.org/resource/Aristida_purpurea 0
# Cal Ripken Jr http://dbpedia.org/resource/Cal_Ripken_Jr 0
# Cal Ripken Jr http://dbpedia.org/resource/Cal_Ripken_Jr. 1
# Cal Ripken Jr http://dbpedia.org/resource/Cal_Ripken_Jr. 1
# Cal Ripken Jr http://dbpedia.org/resource/Cal_Ripken_Jr 0
# Theres Something about Mary http://dbpedia.org/resource/There's_Something_About_Mary 1
# Theres Something about Mary http://dbpedia.org/resource/Something_(Beatles_song) 18
# Theres Something about Mary http://dbpedia.org/resource/There's_Something_About_Mary 1
# Aliens http://dbpedia.org/resource/Aliens 0
# Aliens http://dbpedia.org/resource/Aliens_(film) 7
# Aliens http://dbpedia.org/resource/Extraterrestrial_life 19
# Aliens http://dbpedia.org/resource/Aliens 0
# Warcraft II Tides of Darkness
# Warcraft II Tides of Darkness  9999
# Warcraft II Tides of Darkness http://dbpedia.org/resource/Warcraft 21
# Warcraft II Tides of Darkness http://dbpedia.org/resource/Warcraft 21
# Donkey Kong Country 3 http://dbpedia.org/resource/Donkey_Kong_Country_3 0
# Donkey Kong Country 3 http://dbpedia.org/resource/Donkey_Kong_Country_3:_Dixie_Kong's_Double_Trouble! 30
# Donkey Kong Country 3 http://dbpedia.org/resource/Donkey_Kong 10
# Donkey Kong Country 3 http://dbpedia.org/resource/Donkey_Kong_Country_3 0
# ...
# Plain martin http://dbpedia.org/resource/Plain_martin 0
# Pimenta racemosa http://dbpedia.org/resource/Pimenta_racemosa 0
# Pimenta racemosa http://dbpedia.org/resource/Pimenta_racemosa 0
# Pimenta racemosa http://dbpedia.org/resource/Pimenta_racemosa 0
# Pimenta racemosa http://dbpedia.org/resource/Pimenta_racemosa 0
# Datura stramonium http://dbpedia.org/resource/Datura_stramonium 0
# Datura stramonium http://dbpedia.org/resource/Datura_stramonium 0
# Datura stramonium http://dbpedia.org/resource/Datura_stramonium 0
# Datura stramonium http://dbpedia.org/resource/Datura_stramonium 0
# Crysis 2 http://dbpedia.org/resource/Crysis_2 0
# Crysis 2 http://dbpedia.org/resource/Crysis_2 0
# Crysis 2 http://dbpedia.org/resource/Crysis_2 0
# Crysis 2 http://dbpedia.org/resource/Crysis_2 0
# Battlestar Galactica http://dbpedia.org/resource/Battlestar_Galactica 0
# Battlestar Galactica http://dbpedia.org/resource/Battlestar_Galactica 0
# Battlestar Galactica http://dbpedia.org/resource/Battlestar_Galactica 0
# Battlestar Galactica http://dbpedia.org/resource/Battlestar_Galactica 0
# GREATER SCAUP http://dbpedia.org/resource/Greater_scaup 0
# [SPOTLIGHT] Something went wrong with text: GREATER SCAUP. Returning nothing
# GREATER SCAUP  9999
# GREATER SCAUP http://dbpedia.org/resource/Greater_scaup 0
# Crysis http://dbpedia.org/resource/Crysis 0
# Crysis http://dbpedia.org/resource/Crysis 0
# Crysis http://dbpedia.org/resource/Crysis 0
# Crysis http://dbpedia.org/resource/Crysis 0
# Back to the Future http://dbpedia.org/resource/Back_to_the_Future 0
# Back to the Future http://dbpedia.org/resource/Back_to_the_Future 0
# Back to the Future http://dbpedia.org/resource/Future 12
# Back to the Future http://dbpedia.org/resource/Back_to_the_Future 0
# Bill Donovan http://dbpedia.org/resource/Bill_Donovan 0
# Bill Donovan http://dbpedia.org/resource/Bill_Donovan 0
# Bill Donovan http://dbpedia.org/resource/Bill_Donovan 0
# Bill Donovan http://dbpedia.org/resource/Bill_Donovan 0
# Northern Ireland http://dbpedia.org/resource/Northern_Ireland 0
# Northern Ireland http://dbpedia.org/resource/Northern_Ireland 0
# Northern Ireland http://dbpedia.org/resource/Northern_Ireland 0
# Northern Ireland http://dbpedia.org/resource/Northern_Ireland 0
# Commelina benghalensis http://dbpedia.org/resource/Commelina_benghalensis 0
# Commelina benghalensis http://dbpedia.org/resource/Commelina_benghalensis 0
# Commelina benghalensis http://dbpedia.org/resource/Commelina 13
# Commelina benghalensis http://dbpedia.org/resource/Commelina_benghalensis 0
# Raphael of Brooklyn http://dbpedia.org/resource/Raphael_of_Brooklyn 0
# Raphael of Brooklyn http://dbpedia.org/resource/Raphael_of_Brooklyn 0
# Raphael of Brooklyn http://dbpedia.org/resource/Brooklyn 11
# Raphael of Brooklyn http://dbpedia.org/resource/Raphael_of_Brooklyn 0
# Ethiopia http://dbpedia.org/resource/Ethiopia 0
# Ethiopia http://dbpedia.org/resource/Ethiopia 0
# Ethiopia http://dbpedia.org/resource/Ethiopia 0
# Ethiopia http://dbpedia.org/resource/Ethiopia 0
# Andrei Rublev http://dbpedia.org/resource/Andrei_Rublev 0
# Andrei Rublev http://dbpedia.org/resource/Andrei_Rublev 0
# Andrei Rublev http://dbpedia.org/resource/Andrei_Rublev 0
# Andrei Rublev http://dbpedia.org/resource/Andrei_Rublev 0
# Yellow-mantled widowbird http://dbpedia.org/resource/Yellow-mantled_widowbird 0
# Yellow-mantled widowbird http://dbpedia.org/resource/Yellow-mantled_widowbird 0
# Yellow-mantled widowbird http://dbpedia.org/resource/Yellow-mantled_widowbird 0
# Yellow-mantled widowbird http://dbpedia.org/resource/Yellow-mantled_widowbird 0
# Cowboys  Aliens
# Cowboys  Aliens  9999
# Cowboys  Aliens http://dbpedia.org/resource/Extraterrestrial_life 18
# Cowboys  Aliens http://dbpedia.org/resource/Extraterrestrial_life 18
# Granbury Lake http://dbpedia.org/resource/Granbury_Lake 0
# Granbury Lake http://dbpedia.org/resource/Lake_Granbury 10
# Granbury Lake http://dbpedia.org/resource/Lake 9
# Granbury Lake http://dbpedia.org/resource/Granbury_Lake 0
# Stuntman Ignition http://dbpedia.org/resource/Stuntman_Ignition 0
# Stuntman Ignition http://dbpedia.org/resource/Stuntman:_Ignition 1
# Stuntman Ignition http://dbpedia.org/resource/Stunt_performer 12
# Stuntman Ignition http://dbpedia.org/resource/Stuntman_Ignition 0
# Echinochloa crus-galli http://dbpedia.org/resource/Echinochloa_crus-galli 0
# Echinochloa crus-galli http://dbpedia.org/resource/Echinochloa_crus-galli 0
# Echinochloa crus-galli http://dbpedia.org/resource/Echinochloa 11
# Echinochloa crus-galli http://dbpedia.org/resource/Echinochloa_crus-galli 0
# Buff-throated apalis http://dbpedia.org/resource/Buff-throated_apalis 0
# Buff-throated apalis http://dbpedia.org/resource/Buff-throated_apalis 0
# Buff-throated apalis http://dbpedia.org/resource/Buff-throated_apalis 0
# Buff-throated apalis http://dbpedia.org/resource/Buff-throated_apalis 0
# Pearl Jam Twenty http://dbpedia.org/resource/Pearl_Jam_Twenty 0
# Pearl Jam Twenty http://dbpedia.org/resource/Pearl_Jam_Twenty 0
# Pearl Jam Twenty http://dbpedia.org/resource/Pearl_Jam_Twenty 0
# Pearl Jam Twenty http://dbpedia.org/resource/Pearl_Jam_Twenty 0
# Halo Combat Evolved http://dbpedia.org/resource/Halo_Combat_Evolved 0
# Halo Combat Evolved http://dbpedia.org/resource/Halo:_Combat_Evolved 1
# Halo Combat Evolved http://dbpedia.org/resource/Halo_Array 13
# Halo Combat Evolved http://dbpedia.org/resource/Halo_Combat_Evolved 0
# I Am a Sex Addict http://dbpedia.org/resource/I_Am_a_Sex_Addict 0
# I Am a Sex Addict http://dbpedia.org/resource/I_Am_a_Sex_Addict 0
# I Am a Sex Addict http://dbpedia.org/resource/I_Am_(Yo_Gotti_album) 13
# I Am a Sex Addict http://dbpedia.org/resource/I_Am_a_Sex_Addict 0
# Green http://dbpedia.org/resource/Green 0
# Green http://dbpedia.org/resource/Green 0
# [SPOTLIGHT] Something went wrong with text: Green. Returning nothing
# Green  9999
# Green http://dbpedia.org/resource/Green 0
# Typha latifolia http://dbpedia.org/resource/Typha_latifolia 0
# Typha latifolia http://dbpedia.org/resource/Typha_latifolia 0
# Typha latifolia http://dbpedia.org/resource/Typha_latifolia 0
# Typha latifolia http://dbpedia.org/resource/Typha_latifolia 0
# Dubai International Airport http://dbpedia.org/resource/Dubai_International_Airport 0
# Dubai International Airport http://dbpedia.org/resource/Dubai_International_Airport 0
# Dubai International Airport http://dbpedia.org/resource/Dubai_International_Airport 0
# Dubai International Airport http://dbpedia.org/resource/Dubai_International_Airport 0
# Siberian tiger http://dbpedia.org/resource/Siberian_tiger 0
# Siberian tiger http://dbpedia.org/resource/Siberian_tiger 0
# Siberian tiger http://dbpedia.org/resource/Siberian_tiger 0
# Siberian tiger http://dbpedia.org/resource/Siberian_tiger 0
# Just Go with It http://dbpedia.org/resource/Just_Go_with_It 0
# Just Go with It http://dbpedia.org/resource/Just_Go_with_It 0
# Just Go with It http://dbpedia.org/resource/Just_Go_(album) 7
# Just Go with It http://dbpedia.org/resource/Just_Go_with_It 0
# WAPITI OR ELK
# WAPITI OR ELK  9999
# WAPITI OR ELK http://dbpedia.org/resource/Oregon 11
# WAPITI OR ELK http://dbpedia.org/resource/Oregon 11
# When Harry Met Sally http://dbpedia.org/resource/When_Harry_Met_Sally 0
# When Harry Met Sally http://dbpedia.org/resource/When_Harry_Met_Sally... 3
# When Harry Met Sally http://dbpedia.org/resource/When_Harry_Met_Sally... 3
# When Harry Met Sally http://dbpedia.org/resource/When_Harry_Met_Sally 0
# Napaktulik-Lake
# Napaktulik-Lake  9999
# [SPOTLIGHT] Something went wrong with text: Napaktulik-Lake. Returning nothing
# Napaktulik-Lake  9999
# Napaktulik-Lake  9999
# Verbena rigida http://dbpedia.org/resource/Verbena_rigida 0
# Verbena rigida http://dbpedia.org/resource/Verbena_rigida 0
# Verbena rigida http://dbpedia.org/resource/Verbena 7
# Verbena rigida http://dbpedia.org/resource/Verbena_rigida 0
# UFC Personal Trainer http://dbpedia.org/resource/UFC_Personal_Trainer 0
# UFC Personal Trainer http://dbpedia.org/resource/UFC_Personal_Trainer 0
# UFC Personal Trainer http://dbpedia.org/resource/Personal_trainer 4
# UFC Personal Trainer http://dbpedia.org/resource/UFC_Personal_Trainer 0
# Phil Niekro http://dbpedia.org/resource/Phil_Niekro 0
# Phil Niekro http://dbpedia.org/resource/Phil_Niekro 0
# Phil Niekro http://dbpedia.org/resource/Phil_Niekro 0
# Phil Niekro http://dbpedia.org/resource/Phil_Niekro 0
# Twisted Metal 3 http://dbpedia.org/resource/Twisted_Metal_3 0
# Twisted Metal 3 http://dbpedia.org/resource/Twisted_Metal_III 3
# Twisted Metal 3 http://dbpedia.org/resource/Twisted_Metal 2
# Twisted Metal 3 http://dbpedia.org/resource/Twisted_Metal_3 0
# Freaks http://dbpedia.org/resource/Freaks 0
# Freaks http://dbpedia.org/resource/Freakshow 3
# [SPOTLIGHT] Something went wrong with text: Freaks. Returning nothing
# Freaks  9999
# Freaks http://dbpedia.org/resource/Freaks 0
# Star Trek Enterprise http://dbpedia.org/resource/Star_Trek_Enterprise 0
# Star Trek Enterprise http://dbpedia.org/resource/Star_Trek:_Enterprise 1
# Star Trek Enterprise http://dbpedia.org/resource/Star_Trek:_Enterprise 1
# Star Trek Enterprise http://dbpedia.org/resource/Star_Trek_Enterprise 0
# Turnera ulmifolia http://dbpedia.org/resource/Turnera_ulmifolia 0
# Turnera ulmifolia http://dbpedia.org/resource/Turnera_ulmifolia 0
# Turnera ulmifolia http://dbpedia.org/resource/Turnera_ulmifolia 0
# Turnera ulmifolia http://dbpedia.org/resource/Turnera_ulmifolia 0
# Gladiator http://dbpedia.org/resource/Gladiator 0
# Gladiator http://dbpedia.org/resource/Gladiator 0
# [SPOTLIGHT] Something went wrong with text: Gladiator. Returning nothing
# Gladiator  9999
# Gladiator http://dbpedia.org/resource/Gladiator 0
# A Serious Man http://dbpedia.org/resource/A_Serious_Man 0
# A Serious Man http://dbpedia.org/resource/A_Serious_Man 0
# A Serious Man http://dbpedia.org/resource/A_Serious_Man 0
# A Serious Man http://dbpedia.org/resource/A_Serious_Man 0
# Carex utriculata http://dbpedia.org/resource/Carex_utriculata 0
# Carex utriculata http://dbpedia.org/resource/Carex_utriculata 0
# Carex utriculata http://dbpedia.org/resource/Carex 11
# Carex utriculata http://dbpedia.org/resource/Carex_utriculata 0
# Conflict Denied Ops
# Conflict Denied Ops  9999
# Conflict Denied Ops http://dbpedia.org/resource/Denial 15
# Conflict Denied Ops http://dbpedia.org/resource/Denial 15
# Buddy Rosar http://dbpedia.org/resource/Buddy_Rosar 0
# Buddy Rosar http://dbpedia.org/resource/Buddy_Rosar 0
# Buddy Rosar http://dbpedia.org/resource/Buddy_Rosar 0
# Buddy Rosar http://dbpedia.org/resource/Buddy_Rosar 0
# Aeschynomene indica http://dbpedia.org/resource/Aeschynomene_indica 0
# Aeschynomene indica http://dbpedia.org/resource/Aeschynomene_indica 0
# Aeschynomene indica http://dbpedia.org/resource/Aeschynomene 7
# Aeschynomene indica http://dbpedia.org/resource/Aeschynomene_indica 0
# Mongolia http://dbpedia.org/resource/Mongolia 0
# Mongolia http://dbpedia.org/resource/Mongolia 0
# Mongolia http://dbpedia.org/resource/Mongolia 0
# Mongolia http://dbpedia.org/resource/Mongolia 0
# Nepalese Rupee http://dbpedia.org/resource/Nepalese_Rupee 0
# Nepalese Rupee http://dbpedia.org/resource/Nepalese_rupee 0
# Nepalese Rupee http://dbpedia.org/resource/Nepalese_rupee 0
# Nepalese Rupee http://dbpedia.org/resource/Nepalese_Rupee 0
# CERULEAN WARBLER http://dbpedia.org/resource/Cerulean_warbler 0
# [SPOTLIGHT] Something went wrong with text: CERULEAN WARBLER. Returning nothing
# CERULEAN WARBLER  9999
# CERULEAN WARBLER http://dbpedia.org/resource/Cerulean_warbler 0
# Need for Speed ProStreet http://dbpedia.org/resource/Need_for_Speed_ProStreet 0
# Need for Speed ProStreet http://dbpedia.org/resource/Need_for_Speed:_ProStreet 1
# Need for Speed ProStreet http://dbpedia.org/resource/Speed 19
# Need for Speed ProStreet http://dbpedia.org/resource/Need_for_Speed_ProStreet 0
# Sanjuro http://dbpedia.org/resource/Sanjuro 0
# Sanjuro http://dbpedia.org/resource/Sanjuro 0
# Sanjuro http://dbpedia.org/resource/Sanjuro 0
# Sanjuro http://dbpedia.org/resource/Sanjuro 0
# Misery http://dbpedia.org/resource/Misery 0
# Misery http://dbpedia.org/resource/Misery_lit 4
# Misery http://dbpedia.org/resource/Misery_(film) 7
# Misery http://dbpedia.org/resource/Misery 0
# New Dinar
# New Dinar  9999
# New Dinar http://dbpedia.org/resource/Dinar 4
# New Dinar http://dbpedia.org/resource/Dinar 4
# foxnews http://dbpedia.org/resource/Fox_News 1
# foxnews http://dbpedia.org/resource/Fox_News 1
# foxnews http://dbpedia.org/resource/Fox_News 1
# No Strings Attached http://dbpedia.org/resource/No_Strings_Attached 0
# No Strings Attached http://dbpedia.org/resource/No_Strings_Attached 0
# No Strings Attached http://dbpedia.org/resource/No_Strings 9
# No Strings Attached http://dbpedia.org/resource/No_Strings_Attached 0
# Luis Gonzalez http://dbpedia.org/resource/Luis_Gonzalez 0
# Luis Gonzalez http://dbpedia.org/resource/Luis_Gonzalez 0
# Luis Gonzalez http://dbpedia.org/resource/Luis_Gonzalez_(outfielder) 13
# Luis Gonzalez http://dbpedia.org/resource/Luis_Gonzalez 0
# Cape Verde http://dbpedia.org/resource/Cape_Verde 0
# Cape Verde http://dbpedia.org/resource/Cape_Verde 0
# Cape Verde http://dbpedia.org/resource/Cape_Verde 0
# Cape Verde http://dbpedia.org/resource/Cape_Verde 0
# Ed Wood http://dbpedia.org/resource/Ed_Wood 0
# Ed Wood http://dbpedia.org/resource/Ed_Wood 0
# Ed Wood http://dbpedia.org/resource/Ed_Wood 0
# Ed Wood http://dbpedia.org/resource/Ed_Wood 0
# Fuel http://dbpedia.org/resource/Fuel 0
# Fuel http://dbpedia.org/resource/Fuel 0
# Fuel http://dbpedia.org/resource/Fuel 0
# Fuel http://dbpedia.org/resource/Fuel 0
# The Truman Show http://dbpedia.org/resource/The_Truman_Show 0
# The Truman Show http://dbpedia.org/resource/The_Truman_Show 0
# The Truman Show http://dbpedia.org/resource/The_Truman_Show 0
# The Truman Show http://dbpedia.org/resource/The_Truman_Show 0
# Scientific American http://dbpedia.org/resource/Scientific_American 0
# Scientific American http://dbpedia.org/resource/Scientific_American 0
# Scientific American http://dbpedia.org/resource/Scientific_American 0
# Scientific American http://dbpedia.org/resource/Scientific_American 0
# West Side Story http://dbpedia.org/resource/West_Side_Story 0
# West Side Story http://dbpedia.org/resource/West_Side_Story 0
# West Side Story http://dbpedia.org/resource/West_Side_Story 0
# West Side Story http://dbpedia.org/resource/West_Side_Story 0
# Bronze sunbird http://dbpedia.org/resource/Bronze_sunbird 0
# Bronze sunbird http://dbpedia.org/resource/Bronzy_sunbird 1
# Bronze sunbird http://dbpedia.org/resource/Sunbird 7
# Bronze sunbird http://dbpedia.org/resource/Bronze_sunbird 0
# Brunei Dollar http://dbpedia.org/resource/Brunei_Dollar 0
# Brunei Dollar http://dbpedia.org/resource/Brunei_dollar 0
# Brunei Dollar http://dbpedia.org/resource/Brunei_dollar 0
# Brunei Dollar http://dbpedia.org/resource/Brunei_Dollar 0
# Swamp palm bulbul http://dbpedia.org/resource/Swamp_palm_bulbul 0
# Swamp palm bulbul http://dbpedia.org/resource/Swamp_palm_bulbul 0
# Swamp palm bulbul http://dbpedia.org/resource/Swamp_palm_bulbul 0
# Swamp palm bulbul http://dbpedia.org/resource/Swamp_palm_bulbul 0
# Mike Tiernan http://dbpedia.org/resource/Mike_Tiernan 0
# Mike Tiernan http://dbpedia.org/resource/Mike_Tiernan 0
# Mike Tiernan http://dbpedia.org/resource/Mike_Tiernan 0
# Mike Tiernan http://dbpedia.org/resource/Mike_Tiernan 0
# Goodfellas http://dbpedia.org/resource/Goodfellas 0
# Goodfellas http://dbpedia.org/resource/Goodfellas 0
# Goodfellas http://dbpedia.org/resource/Goodfellas 0
# Goodfellas http://dbpedia.org/resource/Goodfellas 0
# PAINTED TURTLE http://dbpedia.org/resource/Painted_turtle 0
# [SPOTLIGHT] Something went wrong with text: PAINTED TURTLE. Returning nothing
# PAINTED TURTLE  9999
# PAINTED TURTLE http://dbpedia.org/resource/Painted_turtle 0
# Rashmon
# Rashmon  9999
# [SPOTLIGHT] Something went wrong with text: Rashmon. Returning nothing
# Rashmon  9999
# Rashmon  9999
# Sherlock Holmes http://dbpedia.org/resource/Sherlock_Holmes 0
# Sherlock Holmes http://dbpedia.org/resource/Sherlock_Holmes 0
# Sherlock Holmes http://dbpedia.org/resource/Sherlock_Holmes 0
# Sherlock Holmes http://dbpedia.org/resource/Sherlock_Holmes 0
# MLB 2K11 http://dbpedia.org/resource/MLB_2K11 0
# MLB 2K11 http://dbpedia.org/resource/Major_League_Baseball_2K11 18
# MLB 2K11 http://dbpedia.org/resource/Major_League_Baseball_2K11 18
# MLB 2K11 http://dbpedia.org/resource/MLB_2K11 0

# %% [markdown]
# ## Porównanie uzyskanych rezultatów

# %%
expected_results = pd.read_csv("data/Round 1/gt/CEA_Round1_gt.csv", 
                                header=None, 
                                names=['Table_id', 'Column_id', 'Row_id', 'Expected_annotations'])

def compare_results(results: pd.DataFrame, expected_results: pd.DataFrame):
    # Precision = (# correctly annotated cells) / (# annotated cells)
    # Recall = (# correctly annotated cells) / (# target cells)    
    correctly_annotated_cells = 0
    annotated_cells = len(results.index)
    target_cells = len(expected_results.index)

    final_df = pd.merge(results, expected_results,
                        how="left", on=['Table_id', 'Column_id', 'Row_id'])

    for _, row in final_df.iterrows():
        if row['text'] is None or row['annotation'] is None:
            annotated_cells -=1
            continue
        if str(row['annotation']) in row['Expected_annotations']:
            correctly_annotated_cells += 1
    
    precision = correctly_annotated_cells/annotated_cells
    recall = correctly_annotated_cells/target_cells

    return final_df, precision, recall

# %%
check_url_results = pd.read_csv("check_url_results.csv", header=0)
_, precision, recall = compare_results(check_url_results, expected_results)
print(f'Samodzielne tworzenie url: precyzja {round(precision,2)}')
# print(f'check_url_results recall {round(recall,2)}')


dbpedia_lookup_results = pd.read_csv("dbpedia_lookup_results.csv", header=0)
_, precision, recall = compare_results(dbpedia_lookup_results, expected_results)
print(f'DBpedia Lookup Service: precyzja {round(precision,2)}')
# print(f'DBpedia Lookup Service recall {round(recall,2)}')


spotlight_lookup_results = pd.read_csv("spotlight_lookup_results.csv", header=0)
_, precision, recall = compare_results(spotlight_lookup_results, expected_results)
print(f'DBpedia Spotlight: precyzja {round(precision,2)}')
# print(f'DBpedia Spotlight recall {round(recall,2)}')


all_results = pd.read_csv("all_results.csv", header=0)
_, precision, recall = compare_results(all_results, expected_results)
print(f'Ostateczny wynik: precyzja {round(precision,2)}')
# print(f'Ostateczny wynik: recall {round(recall,2)}')
# Out:
# Samodzielne tworzenie url: precyzja 0.79
# DBpedia Lookup Service: precyzja 0.8
# DBpedia Spotlight: precyzja 0.68
# Ostateczny wynik: precyzja 0.89

# %% [markdown]
# ## Podsumowanie
#
# Wyniki okazały się zgodne z oczekiwaniami. Najmniej skutecznym samodzielnym sposobem okazało się wykorzystanie narzędzia DBpedia Spotlight API. Tak jak opisywane wcześniej jest to narzędzie najlepiej radzące sobie w przypadku dłuższych tekstów, a nie jak w przypadku tego zadania pojedynczych słów/ nazw. Ciekawym faktem jest iż wykorzystanie sposobu ręcznego tworzenia adresów ma podobną skuteczność jak wykorzystanie narzędzia DBpedia Lookup. Ostateczny wynik, łączący wszystkie metody uzyskał precyzje ~0.89 co wydaje się zadowalającym rezultatem.

# %% [markdown]
# ## Propozycje możliwego dalszego rozwoju
#
# Na podstawie analizy poprawnie i niepoprawnie rozpoznanych danych możliwe byłoby dalsze usprawnianie całego systemu. Trzeci sposób anotacji (DBpedia Spootligh) zdecydowanie zyskałby w momencie w którym dołączona do zapytania byłaby chociaż kategoria do jakiej się odnosi. Narzędzie pozwala na bardzo rozbudowane zapytania, które w tym przypadku pojedynczych krótkich tekstów ciężko było wykorzystać.
#
# Np. niektóre komórki zawierały pierwszą literę imienia oraz nazwisko. W przypadku poświęcenia dodatkowego czasu na wykrycie takiej specyficznej sytuacji, możliwe byłoby dopisanie kategori do zapytania lub wyszukanie encji za pomocą samego nazwiska.

# %% [markdown]
# # Bibliografia
#
# * https://www.dbpedia.org/resources/lookup/
# * https://github.com/dbpedia/dbpedia-lookup
# * https://www.dbpedia-spotlight.org/
# * http://www.cs.ox.ac.uk/isg/challenges/sem-tab/
# * http://ceur-ws.org/Vol-2553/
# * http://ceur-ws.org/Vol-2775/paper9.pdf
# * http://ceur-ws.org/Vol-2553/paper5.pdf
